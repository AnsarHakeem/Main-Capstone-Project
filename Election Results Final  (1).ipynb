# %% [markdown]
#                      REAL TIME ELECTION RESULTS , PORTUGAL 2019
#                             DSML CAPSTONE PROJECT

# %% [markdown]
# NAME: ANSAR MH

# %% [markdown]
# ORGANIZATION: ENTRI ELEVATE

# %% [markdown]
#                                PROJECT OVERVIEW
# Elections are part of a system that the people selecting one or more for the betterement of the society. And those who winning the election are committed to the society and its people. to serve them , to give them what they wanted and creating a better society without much problems are the aim of it

# %% [markdown]
#                                OBJECTIVE
# This project is for analysing the results of election happens in portugal 2019. aim of the project to know who habe the strong hold in protugal and what they getting to winning the elections

# %% [markdown]
#                                 DATA DESCRIPTION
# Source : UCI Machine Learning Repository
# Link : https://archive.ics.uci.edu/dataset/513/real+time+election+results+portugal+2019
# Features : Instances - 21643
#            Features - 29

# %% [markdown]
#                                   IMPORTING LIBRARIES
# NUMPY : Numpy is a python library used for numerical computing
# PANDAS : Pandas is a python library used for data manipulation and analysis
# SEABORN : Seaborn is a python library designed for creating attractive and informative statistical graphics
# MATPLOTLIB : Matplotlib is a python library for vreationg static, animated and interactive visualizations
# SciKit Learn : Scikit Learn is a popular python library for machine learning.It provides simple and efficiet tools for data mining and analysis

# %%
#IMPORTING LIBRARIES
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler 
from sklearn.feature_selection import SelectKBest,f_regression
from sklearn.model_selection import train_test_split,RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib

# %%
#LOADING THE DATA
data=pd.read_csv('ElectionData.csv')

# %%
#PROCESSING DATA INTO DATAFRAME
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    TimeElapsed                 time        territoryName  totalMandates  \
# 0            0  2019-10-06 20:10:02  Território Nacional              0
# 1            0  2019-10-06 20:10:02  Território Nacional              0
# 2            0  2019-10-06 20:10:02  Território Nacional              0
# 3            0  2019-10-06 20:10:02  Território Nacional              0
# 4            0  2019-10-06 20:10:02  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                   2.5       8874  ...                 52.66
# 1                   2.5       8874  ...                 52.66
# 2                   2.5       8874  ...                 52.66
# 3                   2.5       8874  ...                 52.66
# 4                   2.5       8874  ...                 52.66
#
#    pre.subscribedVoters  pre.totalVoters    Party  Mandates  Percentage  \
# 0                813743           428546       PS         0       38.29
# 1                813743           428546  PPD/PSD         0       33.28
# 2                813743           428546     B.E.         0        6.81
# 3                813743           428546   CDS-PP         0        4.90
# 4                813743           428546  PCP-PEV         0        4.59
#
#    validVotesPercentage   Votes  Hondt  FinalMandates
# 0                 40.22  147993     94            106
# 1                 34.95  128624     81             77
# 2                  7.15   26307     16             19
# 3                  5.14   18923     12              5
# 4                  4.83   17757     11             12
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#        TimeElapsed                 time territoryName  totalMandates  \
# 21638          265  2019-10-07 00:35:01         Viseu              8
# 21639          265  2019-10-07 00:35:01         Viseu              8
# 21640          265  2019-10-07 00:35:01         Viseu              8
# 21641          265  2019-10-07 00:35:01         Viseu              8
# 21642          265  2019-10-07 00:35:01         Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# 21638                  0          277                  277        4995
# 21639                  0          277                  277        4995
# 21640                  0          277                  277        4995
# 21641                  0          277                  277        4995
# 21642                  0          277                  277        4995
#
#        blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 21638                  2.81       3700  ...                 51.28
# 21639                  2.81       3700  ...                 51.28
# 21640                  2.81       3700  ...                 51.28
# 21641                  2.81       3700  ...                 51.28
# 21642                  2.81       3700  ...                 51.28
#
#        pre.subscribedVoters  pre.totalVoters  Party  Mandates  Percentage  \
# 21638                371931           190712     NC         0        0.19
# 21639                371931           190712    PNR         0        0.18
# 21640                371931           190712    MPT         0        0.14
# 21641                371931           190712    PTP         0        0.13
# 21642                371931           190712    JPP         0        0.07
#
#        validVotesPercentage  Votes  Hondt  FinalMandates
# 21638                  0.20    332      0              0
# 21639                  0.19    326      0              0
# 21640                  0.15    256      0              0
# 21641                  0.14    239      0              0
# 21642                  0.07    118      0              0
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  object
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
#  13  totalVoters               21643 non-null  int64
#  14  pre.blankVotes            21643 non-null  int64
#  15  pre.blankVotesPercentage  21643 non-null  float64
#  16  pre.nullVotes             21643 non-null  int64
#  17  pre.nullVotesPercentage   21643 non-null  float64
#  18  pre.votersPercentage      21643 non-null  float64
#  19  pre.subscribedVoters      21643 non-null  int64
#  20  pre.totalVoters           21643 non-null  int64
#  21  Party                     21643 non-null  object
#  22  Mandates                  21643 non-null  int64
#  23  Percentage                21643 non-null  float64
#  24  validVotesPercentage      21643 non-null  float64
#  25  Votes                     21643 non-null  int64
#  26  Hondt                     21643 non-null  int64
#  27  FinalMandates             21643 non-null  int64
# dtypes: float64(8), int64(17), object(3)
# memory usage: 4.6+ MB

# %%
df.shape
# Out:
# (21643, 28)

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# Hondt                         int64
# FinalMandates                 int64
# dtype: object

# %%
df.describe()
# Out:
#         TimeElapsed  totalMandates  availableMandates   numParishes  \
# count  21643.000000   21643.000000       21643.000000  21643.000000
# mean     133.146052      11.544795          11.499284    309.956013
# std       77.651193      31.314567          31.738783    659.055911
# min        0.000000       0.000000           0.000000     54.000000
# 25%       65.000000       1.000000           0.000000     75.000000
# 50%      135.000000       4.000000           3.000000    147.000000
# 75%      200.000000       9.000000           9.000000    242.000000
# max      265.000000     226.000000         226.000000   3092.000000
#
#        numParishesApproved     blankVotes  blankVotesPercentage     nullVotes  \
# count         21643.000000   21643.000000          21643.000000  21643.000000
# mean            261.090237    8875.066673              2.621629   6148.068752
# std             583.377428   21484.874088              0.795289  14735.469269
# min               3.000000      19.000000              0.530000     39.000000
# 25%              67.000000    1188.000000              2.230000   1094.000000
# 50%             120.000000    2998.000000              2.640000   2232.000000
# 75%             208.000000    6889.000000              2.980000   4121.000000
# max            3092.000000  129599.000000              5.460000  88539.000000
#
#        nullVotesPercentage  votersPercentage  ...  pre.nullVotesPercentage  \
# count         21643.000000      21643.000000  ...             21643.000000
# mean              1.961471         51.983722  ...                 1.777442
# std               0.375250          4.854380  ...                 0.388798
# min               1.340000         35.980000  ...                 1.140000
# 25%               1.720000         50.290000  ...                 1.520000
# 50%               1.870000         53.130000  ...                 1.690000
# 75%               2.230000         54.550000  ...                 1.970000
# max               3.350000         59.870000  ...                 3.120000
#
#        pre.votersPercentage  pre.subscribedVoters  pre.totalVoters  \
# count          21643.000000          2.164300e+04     2.164300e+04
# mean              54.549372          6.378503e+05     3.594932e+05
# std                4.964948          1.544418e+06     8.763729e+05
# min               40.870000          6.383000e+03     3.215000e+03
# 25%               51.210000          1.289260e+05     6.964400e+04
# 50%               56.260000          2.284970e+05     1.102730e+05
# 75%               58.220000          3.933140e+05     2.276200e+05
# max               62.580000          9.439701e+06     5.380451e+06
#
#            Mandates    Percentage  validVotesPercentage         Votes  \
# count  21643.000000  21643.000000          21643.000000  2.164300e+04
# mean       0.565495      4.968484              5.207232  1.585209e+04
# std        4.421804     10.379967             10.881108  9.310605e+04
# min        0.000000      0.020000              0.020000  1.000000e+00
# 25%        0.000000      0.220000              0.230000  2.360000e+02
# 50%        0.000000      0.620000              0.650000  7.900000e+02
# 75%        0.000000      3.010000              3.160000  4.510000e+03
# max      106.000000     49.110000             51.420000  1.866407e+06
#
#               Hondt  FinalMandates
# count  21643.000000   21643.000000
# mean       1.126138       1.126138
# std        6.293552       6.872644
# min        0.000000       0.000000
# 25%        0.000000       0.000000
# 50%        0.000000       0.000000
# 75%        0.000000       0.000000
# max       94.000000     106.000000
#
# [8 rows x 25 columns]

# %%
#CHECKING NULL VALUES
df.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
#CHECKING DUPLICATES
df.duplicated().sum()
# Out:
# 0

# %%
#FINDINGF NUMERICAL COLUMNS
numerical_columns=df.select_dtypes(include='number')
numerical_columns
# Out:
#        TimeElapsed  totalMandates  availableMandates  numParishes  \
# 0                0              0                226         3092
# 1                0              0                226         3092
# 2                0              0                226         3092
# 3                0              0                226         3092
# 4                0              0                226         3092
# ...            ...            ...                ...          ...
# 21638          265              8                  0          277
# 21639          265              8                  0          277
# 21640          265              8                  0          277
# 21641          265              8                  0          277
# 21642          265              8                  0          277
#
#        numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# 0                     1081        9652                  2.50       8874
# 1                     1081        9652                  2.50       8874
# 2                     1081        9652                  2.50       8874
# 3                     1081        9652                  2.50       8874
# 4                     1081        9652                  2.50       8874
# ...                    ...         ...                   ...        ...
# 21638                  277        4995                  2.81       3700
# 21639                  277        4995                  2.81       3700
# 21640                  277        4995                  2.81       3700
# 21641                  277        4995                  2.81       3700
# 21642                  277        4995                  2.81       3700
#
#        nullVotesPercentage  votersPercentage  ...  pre.nullVotesPercentage  \
# 0                     2.30             51.36  ...                     1.91
# 1                     2.30             51.36  ...                     1.91
# 2                     2.30             51.36  ...                     1.91
# 3                     2.30             51.36  ...                     1.91
# 4                     2.30             51.36  ...                     1.91
# ...                    ...               ...  ...                      ...
# 21638                 2.08             51.04  ...                     1.90
# 21639                 2.08             51.04  ...                     1.90
# 21640                 2.08             51.04  ...                     1.90
# 21641                 2.08             51.04  ...                     1.90
# 21642                 2.08             51.04  ...                     1.90
#
#        pre.votersPercentage  pre.subscribedVoters  pre.totalVoters  Mandates  \
# 0                     52.66                813743           428546         0
# 1                     52.66                813743           428546         0
# 2                     52.66                813743           428546         0
# 3                     52.66                813743           428546         0
# 4                     52.66                813743           428546         0
# ...                     ...                   ...              ...       ...
# 21638                 51.28                371931           190712         0
# 21639                 51.28                371931           190712         0
# 21640                 51.28                371931           190712         0
# 21641                 51.28                371931           190712         0
# 21642                 51.28                371931           190712         0
#
#        Percentage  validVotesPercentage   Votes  Hondt  FinalMandates
# 0           38.29                 40.22  147993     94            106
# 1           33.28                 34.95  128624     81             77
# 2            6.81                  7.15   26307     16             19
# 3            4.90                  5.14   18923     12              5
# 4            4.59                  4.83   17757     11             12
# ...           ...                   ...     ...    ...            ...
# 21638        0.19                  0.20     332      0              0
# 21639        0.18                  0.19     326      0              0
# 21640        0.14                  0.15     256      0              0
# 21641        0.13                  0.14     239      0              0
# 21642        0.07                  0.07     118      0              0
#
# [21643 rows x 25 columns]

# %% [markdown]
# Data contains 25 numerical columns

# %%
#FINDING CATEGORICAL COLUMNS
categorical_columns=df.select_dtypes(include=['object'])
categorical_columns
# Out:
#                       time        territoryName    Party
# 0      2019-10-06 20:10:02  Território Nacional       PS
# 1      2019-10-06 20:10:02  Território Nacional  PPD/PSD
# 2      2019-10-06 20:10:02  Território Nacional     B.E.
# 3      2019-10-06 20:10:02  Território Nacional   CDS-PP
# 4      2019-10-06 20:10:02  Território Nacional  PCP-PEV
# ...                    ...                  ...      ...
# 21638  2019-10-07 00:35:01                Viseu       NC
# 21639  2019-10-07 00:35:01                Viseu      PNR
# 21640  2019-10-07 00:35:01                Viseu      MPT
# 21641  2019-10-07 00:35:01                Viseu      PTP
# 21642  2019-10-07 00:35:01                Viseu      JPP
#
# [21643 rows x 3 columns]

# %% [markdown]
# Data contains 3 categorical columns

# %% [markdown]
#                                    DROPPING UNWANTED COLUMNS FROM THE DATA
# Droping the unwanted columns that contains Nan values and some data that is not as important for the project. dropping unwanted columns will give us smooth functioning and quick results without any problems

# %%
#DROP UNWANTED COLUMNS
df=df.drop(columns=['time','Party','territoryName'])

# %% [markdown]
#                                               VISUALIZATION
# Visualization of the data will give you an idea about the complete data. Through visualization we can find outliers, skewness and kurtosis in the data and through that we can make what to use to remove these items to create a good data

# %%
#VISUALIZATION OF DATA 
#BOXPLOT
plt.figure(figsize=(15,12))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
#SCATTERPLOT
plt.figure(figsize=(30,27))
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
#HISTOGRAM
plt.hist(df,bins=20)
# Out:
# (array([[2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [1.7169e+04, 2.3160e+03, 3.3200e+02, 8.2000e+02, 4.0000e+01,
#          2.1000e+01, 6.3000e+01, 4.2000e+01, 4.2000e+01, 2.1000e+01,
#          2.1000e+01, 4.2000e+01, 4.2000e+01, 6.3000e+01, 2.1000e+01,
#          6.3000e+01, 4.2000e+01, 4.2000e+01, 1.6800e+02, 2.7300e+02],
#         [1.9444e+04, 9.3300e+02, 3.2100e+02, 8.4000e+01, 8.4000e+01,
#          4.2000e+01, 6.3000e+01, 8.4000e+01, 8.4000e+01, 1.2600e+02,
#          3.7800e+02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [1.7169e+04, 2.3160e+03, 3.3200e+02, 8.2000e+02, 4.0000e+01,
#          2.1000e+01, 4.2000e+01, 4.2000e+01, 6.3000e+01, 2.1000e+01,
#          0.0000e+00, 4.2000e+01, 6.3000e+01, 4.2000e+01, 4.2000e+01,
#          4.2000e+01, 6.3000e+01, 2.1000e+01, 1.8900e+02, 2.7300e+02],
#         [1.8941e+04, 1.1650e+03, 5.7100e+02, 8.4000e+01, 8.4000e+01,
#          2.1000e+01, 6.3000e+01, 1.0500e+02, 6.3000e+01, 8.4000e+01,
#          1.8900e+02, 2.7300e+02, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1540e+04, 3.4000e+01, 4.0000e+01, 2.9000e+01, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]]),
#  array([      0.  ,  471985.05,  943970.1 , 1415955.15, 1887940.2 ,
#         2359925.25, 2831910.3 , 3303895.35, 3775880.4 , 4247865.45,
#         4719850.5 , 5191835.55, 5663820.6 , 6135805.65, 6607790.7 ,
#         7079775.75, 7551760.8 , 8023745.85, 8495730.9 , 8967715.95,
#         9439701.  ]),
#  <a list of 25 BarContainer objects>)

# %%
for i in numerical_columns:
    plt.hist(df[i])
    plt.show()

# %%
#FINDING OUTLIERS

def outliers(df):
    for col in df.select_dtypes(include=['float64','int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        Lower_Bound = Q1 - (1.5 * IQR)
        Upper_Bound = Q3 + (1.5 * IQR)

        df[col] = df[col].apply( lambda x : Lower_Bound if x < Lower_Bound else Upper_Bound if x > Upper_Bound else x )

    return df

# %%
df1=outliers(df)

# %%
df1.head()
# Out:
#    TimeElapsed  totalMandates  availableMandates  numParishes  \
# 0            0            0.0               22.5        492.5
# 1            0            0.0               22.5        492.5
# 2            0            0.0               22.5        492.5
# 3            0            0.0               22.5        492.5
# 4            0            0.0               22.5        492.5
#
#    numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# 0                419.5      9652.0                   2.5     8661.5
# 1                419.5      9652.0                   2.5     8661.5
# 2                419.5      9652.0                   2.5     8661.5
# 3                419.5      9652.0                   2.5     8661.5
# 4                419.5      9652.0                   2.5     8661.5
#
#    nullVotesPercentage  votersPercentage  ...  pre.nullVotesPercentage  \
# 0                  2.3             51.36  ...                     1.91
# 1                  2.3             51.36  ...                     1.91
# 2                  2.3             51.36  ...                     1.91
# 3                  2.3             51.36  ...                     1.91
# 4                  2.3             51.36  ...                     1.91
#
#    pre.votersPercentage  pre.subscribedVoters  pre.totalVoters  Mandates  \
# 0                 52.66              789896.0         428546.0       0.0
# 1                 52.66              789896.0         428546.0       0.0
# 2                 52.66              789896.0         428546.0       0.0
# 3                 52.66              789896.0         428546.0       0.0
# 4                 52.66              789896.0         428546.0       0.0
#
#    Percentage  validVotesPercentage    Votes  Hondt  FinalMandates
# 0       7.195                 7.555  10921.0    0.0            0.0
# 1       7.195                 7.555  10921.0    0.0            0.0
# 2       6.810                 7.150  10921.0    0.0            0.0
# 3       4.900                 5.140  10921.0    0.0            0.0
# 4       4.590                 4.830  10921.0    0.0            0.0
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(15,12))
sns.boxplot(df1)
# Out:
# <Axes: >

# %% [markdown]
#                                           FEATURE ENGINEERING
# Power Transformer method in python is a feature transformation technique. It is useful for stabilizing variance and minimalising skewness in the data . In this project Iam using yeo johnson method which works with both positive and negetive data.

# %%
#FEATURE ENGINEERING
pt=PowerTransformer(method='yeo-johnson')

# %%
numerical_features=df1.select_dtypes(include=['float64','int64']).columns

# %%
df1[numerical_features]=pt.fit_transform(df1[numerical_features])

# %% [markdown]
#                                         SKEWNESS AND KURTOSIS
# Skewness and Kurtosis are statistical measures used to describe the shape of a data distribution
#
# SKEWNESS
# Positive Skewness
# Negative Skewness
# Zero Skewness
#
# KURTOSIS
# Leptokurtic
# Platykurtic
# Mesokurtic

# %%
#CHECKING SKEW AND KURTOSIS
df1[numerical_features].skew()
# Out:
# TimeElapsed                -0.306219
# totalMandates              -0.025199
# availableMandates           0.122640
# numParishes                 0.005755
# numParishesApproved        -0.053527
# blankVotes                 -0.071032
# blankVotesPercentage        0.020298
# nullVotes                  -0.080674
# nullVotesPercentage         0.041901
# votersPercentage           -0.042573
# subscribedVoters           -0.101867
# totalVoters                -0.084458
# pre.blankVotes             -0.066772
# pre.blankVotesPercentage    0.034540
# pre.nullVotes              -0.095531
# pre.nullVotesPercentage     0.014256
# pre.votersPercentage       -0.184101
# pre.subscribedVoters       -0.097851
# pre.totalVoters            -0.076318
# Mandates                    0.000000
# Percentage                  0.378590
# validVotesPercentage        0.373076
# Votes                      -0.035944
# Hondt                       0.000000
# FinalMandates               0.000000
# dtype: float64

# %%
df2=df1[numerical_features]

# %%
plt.hist(df2,bins=20)
# Out:
# (array([[0.0000e+00, 0.0000e+00, 3.8600e+02, 7.7200e+02, 7.7200e+02,
#          1.1750e+03, 1.6120e+03, 1.2090e+03, 1.6120e+03, 1.6120e+03,
#          1.6120e+03, 2.0150e+03, 1.6120e+03, 2.0150e+03, 2.0150e+03,
#          2.0150e+03, 1.2090e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          5.0550e+03, 0.0000e+00, 9.7100e+02, 0.0000e+00, 1.7550e+03,
#          4.2570e+03, 1.3970e+03, 1.6840e+03, 2.3860e+03, 9.7200e+02,
#          6.1100e+02, 2.5550e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 9.6860e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          5.4200e+02, 1.8730e+03, 1.5310e+03, 2.2430e+03, 1.9710e+03,
#          1.5450e+03, 2.2520e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 2.1600e+03,
#          1.0260e+03, 2.8620e+03, 0.0000e+00, 1.1340e+03, 9.7200e+02,
#          3.1860e+03, 1.8790e+03, 1.9440e+03, 3.1320e+03, 1.0800e+03,
#          0.0000e+00, 1.1340e+03, 0.0000e+00, 1.1340e+03, 0.0000e+00],
#         [0.0000e+00, 1.8000e+02, 2.2000e+02, 7.0000e+02, 7.9100e+02,
#          4.2000e+02, 7.1800e+02, 2.1140e+03, 2.9900e+03, 7.9700e+02,
#          2.4090e+03, 3.0150e+03, 5.7800e+02, 2.4330e+03, 1.5830e+03,
#          8.0500e+02, 7.5600e+02, 0.0000e+00, 1.1340e+03, 0.0000e+00],
#         [0.0000e+00, 3.8000e+02, 0.0000e+00, 6.2300e+02, 8.7200e+02,
#          2.5600e+02, 1.7430e+03, 1.7060e+03, 2.5430e+03, 2.2700e+03,
#          6.6000e+02, 2.0790e+03, 2.4580e+03, 1.7250e+03, 9.1100e+02,
#          6.2900e+02, 2.7880e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 1.0800e+03, 0.0000e+00, 1.8000e+02, 0.0000e+00,
#          2.9000e+02, 5.5300e+02, 2.9690e+03, 3.2150e+03, 1.6550e+03,
#          1.9180e+03, 2.0440e+03, 3.2090e+03, 1.3460e+03, 1.7100e+02,
#          9.2000e+02, 8.7400e+02, 4.2000e+02, 0.0000e+00, 7.9900e+02],
#         [0.0000e+00, 1.8000e+02, 4.0000e+01, 1.3230e+03, 4.1600e+02,
#          4.4700e+02, 8.0200e+02, 2.1710e+03, 2.3190e+03, 1.2460e+03,
#          3.5900e+03, 1.1670e+03, 2.5510e+03, 6.9500e+02, 1.0690e+03,
#          7.5600e+02, 2.8710e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 3.6800e+02, 9.6800e+02, 3.7200e+02,
#          6.1400e+02, 8.6800e+02, 1.2580e+03, 2.0730e+03, 4.1130e+03,
#          2.1590e+03, 1.5950e+03, 1.0410e+03, 1.0160e+03, 1.5350e+03,
#          1.9450e+03, 1.8000e+02, 1.2260e+03, 3.1200e+02, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.2910e+03, 1.9710e+03,
#          2.3000e+02, 2.1800e+02, 8.2200e+02, 2.6910e+03, 1.1890e+03,
#          1.8540e+03, 3.3800e+03, 3.3760e+03, 1.1290e+03, 5.5900e+02,
#          1.0330e+03, 4.5200e+02, 4.8200e+02, 9.6600e+02, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 4.0000e+02, 1.1430e+03, 4.9200e+02,
#          4.2500e+02, 1.0360e+03, 1.3160e+03, 2.5760e+03, 2.3190e+03,
#          2.2710e+03, 1.3780e+03, 3.0690e+03, 8.0500e+02, 4.9200e+02,
#          9.0900e+02, 3.0120e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 4.0000e+02, 1.1430e+03, 5.4300e+02,
#          4.0700e+02, 1.0180e+03, 1.1750e+03, 2.8560e+03, 3.2180e+03,
#          1.8170e+03, 5.7700e+02, 3.1270e+03, 8.6700e+02, 5.5300e+02,
#          8.8600e+02, 3.0560e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 2.2000e+02, 1.6000e+02, 9.7100e+02, 6.8400e+02,
#          3.6000e+01, 1.2910e+03, 1.6230e+03, 3.2240e+03, 2.2050e+03,
#          7.8900e+02, 1.8710e+03, 2.5790e+03, 1.6260e+03, 1.0110e+03,
#          6.7100e+02, 2.6820e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 8.6000e+02, 2.3100e+02, 0.0000e+00, 3.4000e+02,
#          3.2500e+02, 2.7800e+02, 3.1200e+03, 1.6410e+03, 3.0930e+03,
#          2.2750e+03, 3.9080e+03, 4.6200e+02, 1.8970e+03, 4.6000e+02,
#          8.2000e+02, 8.8200e+02, 6.3000e+01, 1.8900e+02, 7.9900e+02],
#         [0.0000e+00, 0.0000e+00, 1.8000e+02, 1.2030e+03, 7.0300e+02,
#          5.0200e+02, 8.8300e+02, 1.9300e+03, 1.9360e+03, 1.9910e+03,
#          2.4680e+03, 1.4510e+03, 3.0700e+03, 1.0980e+03, 6.9100e+02,
#          1.2970e+03, 8.2000e+01, 2.1580e+03, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 3.5100e+02, 0.0000e+00, 4.6400e+02, 1.6500e+03,
#          1.6800e+02, 1.0200e+02, 1.9920e+03, 2.0350e+03, 2.1710e+03,
#          3.9230e+03, 1.1110e+03, 1.7020e+03, 2.2200e+03, 1.1620e+03,
#          2.7000e+02, 1.0520e+03, 0.0000e+00, 1.2700e+03, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 3.4000e+01, 7.4800e+02, 4.1100e+02,
#          2.0420e+03, 1.3100e+03, 2.5790e+03, 8.0000e+02, 4.8600e+02,
#          1.4100e+03, 2.7540e+03, 2.1770e+03, 2.6620e+03, 8.8200e+02,
#          2.7240e+03, 3.0000e+02, 1.5300e+02, 1.7100e+02, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 4.0000e+02, 1.1430e+03, 3.4800e+02,
#          5.6900e+02, 1.0360e+03, 1.3180e+03, 2.5920e+03, 2.3540e+03,
#          2.8380e+03, 7.7500e+02, 3.0920e+03, 7.6500e+02, 4.6600e+02,
#          9.9600e+02, 2.9510e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 4.0000e+02, 1.1430e+03, 5.4300e+02,
#          2.6300e+02, 1.1090e+03, 1.1770e+03, 2.2660e+03, 3.4190e+03,
#          2.2570e+03, 5.7900e+02, 2.6760e+03, 1.3570e+03, 5.3200e+02,
#          9.5000e+02, 2.9720e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 8.0000e+00,
#          1.1010e+03, 4.4950e+03, 1.9900e+03, 1.7670e+03, 2.2320e+03,
#          1.8870e+03, 6.9200e+02, 5.6100e+02, 9.6800e+02, 8.5800e+02,
#          1.1610e+03, 3.9230e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+01,
#          1.2910e+03, 4.2620e+03, 2.0620e+03, 1.6690e+03, 2.2530e+03,
#          1.9070e+03, 6.7100e+02, 6.2200e+02, 9.4900e+02, 8.5800e+02,
#          1.1670e+03, 3.9220e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [1.0000e+01, 1.0300e+02, 3.3000e+02, 4.1500e+02, 4.5700e+02,
#          9.8800e+02, 1.4800e+03, 2.0940e+03, 2.0830e+03, 2.5840e+03,
#          1.6880e+03, 1.7410e+03, 1.2120e+03, 1.0570e+03, 8.4400e+02,
#          9.1600e+02, 3.6410e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          2.1643e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]]),
#  array([-2.78755184, -2.52496286, -2.26237388, -1.9997849 , -1.73719592,
#         -1.47460694, -1.21201796, -0.94942898, -0.68684   , -0.42425102,
#         -0.16166204,  0.10092694,  0.36351592,  0.6261049 ,  0.88869388,
#          1.15128286,  1.41387184,  1.67646082,  1.9390498 ,  2.20163878,
#          2.46422776]),
#  <a list of 25 BarContainer objects>)

# %%
df2=df2.drop(columns=['Mandates','Hondt','FinalMandates'])

# %% [markdown]
#                                              CORRELATION
# Correlation measures the relationship between two variables,indicating how one variabke changes in relation to another. Itb is widely used in data analysis to identify patterns and relationship
#
# TYPES OF CORRELATION
#
# Positive Correlation : Both variables increase together
# Negative Correlation : One variable increases while the other decreases
# No Correlation : No relationship exists between the variables
#
# CORRELATION COEFFICIENT
# The strength and direction of a correlation expressed as a correlation coefficient , which ranges from -1 to +1
# > +1 : Perfect positive correlation
# >  0 : No correlation
# > -1 : Perfect negative correlation

# %%
#CORRELATION
correlation=df2.corr()
correlation
# Out:
#                           TimeElapsed  totalMandates  availableMandates  \
# TimeElapsed                  1.000000       0.749822          -0.626845
# totalMandates                0.749822       1.000000          -0.264027
# availableMandates           -0.626845      -0.264027           1.000000
# numParishes                  0.001273       0.290125           0.162037
# numParishesApproved          0.387991       0.582905          -0.156463
# blankVotes                   0.538633       0.856297           0.027395
# blankVotesPercentage         0.051554       0.125239           0.001134
# nullVotes                    0.554941       0.875597           0.009004
# nullVotesPercentage         -0.199807      -0.261310          -0.062553
# votersPercentage             0.052288       0.318876           0.255823
# subscribedVoters             0.587012       0.895954          -0.011769
# totalVoters                  0.577001       0.890415           0.001864
# pre.blankVotes               0.557561       0.872799           0.015406
# pre.blankVotesPercentage     0.108332       0.178681          -0.011035
# pre.nullVotes                0.573367       0.882849          -0.003521
# pre.nullVotesPercentage     -0.090531      -0.204753          -0.110033
# pre.votersPercentage         0.061075       0.212050           0.203911
# pre.subscribedVoters         0.583511       0.894533          -0.012584
# pre.totalVoters              0.579351       0.890323          -0.001522
# Percentage                   0.029081       0.004637          -0.024213
# validVotesPercentage         0.029017       0.004310          -0.024672
# Votes                        0.380162       0.526818          -0.031009
#
#                           numParishes  numParishesApproved  blankVotes  \
# TimeElapsed                  0.001273             0.387991    0.538633
# totalMandates                0.290125             0.582905    0.856297
# availableMandates            0.162037            -0.156463    0.027395
# numParishes                  1.000000             0.825176    0.466706
# numParishesApproved          0.825176             1.000000    0.688522
# blankVotes                   0.466706             0.688522    1.000000
# blankVotesPercentage         0.327451             0.233761    0.381808
# nullVotes                    0.441930             0.697397    0.958619
# nullVotesPercentage          0.362678             0.214170   -0.174346
# votersPercentage             0.110746             0.039733    0.398694
# subscribedVoters             0.373834             0.657740    0.960351
# totalVoters                  0.368362             0.647428    0.959546
# pre.blankVotes               0.437714             0.680910    0.996520
# pre.blankVotesPercentage     0.313643             0.250937    0.423201
# pre.nullVotes                0.376188             0.658002    0.932149
# pre.nullVotesPercentage      0.042485             0.018030   -0.279369
# pre.votersPercentage        -0.146604            -0.147325    0.279618
# pre.subscribedVoters         0.390926             0.672559    0.962679
# pre.totalVoters              0.373675             0.655205    0.965080
# Percentage                  -0.070716            -0.043480   -0.009146
# validVotesPercentage        -0.068948            -0.042401   -0.008258
# Votes                        0.186187             0.391411    0.556560
#
#                           blankVotesPercentage  nullVotes  \
# TimeElapsed                           0.051554   0.554941
# totalMandates                         0.125239   0.875597
# availableMandates                     0.001134   0.009004
# numParishes                           0.327451   0.441930
# numParishesApproved                   0.233761   0.697397
# blankVotes                            0.381808   0.958619
# blankVotesPercentage                  1.000000   0.174820
# nullVotes                             0.174820   1.000000
# nullVotesPercentage                   0.161887  -0.090835
# votersPercentage                      0.025481   0.400110
# subscribedVoters                      0.176909   0.984724
# totalVoters                           0.160646   0.988782
# pre.blankVotes                        0.335073   0.971477
# pre.blankVotesPercentage              0.965773   0.217198
# pre.nullVotes                         0.119249   0.988773
# pre.nullVotesPercentage              -0.071278  -0.137423
# pre.votersPercentage                 -0.065960   0.244706
# pre.subscribedVoters                  0.177822   0.987510
# pre.totalVoters                       0.167995   0.988997
# Percentage                           -0.012564  -0.010213
# validVotesPercentage                 -0.007818  -0.010292
# Votes                                 0.073904   0.572321
#
#                           nullVotesPercentage  votersPercentage  ...  \
# TimeElapsed                         -0.199807          0.052288  ...
# totalMandates                       -0.261310          0.318876  ...
# availableMandates                   -0.062553          0.255823  ...
# numParishes                          0.362678          0.110746  ...
# numParishesApproved                  0.214170          0.039733  ...
# blankVotes                          -0.174346          0.398694  ...
# blankVotesPercentage                 0.161887          0.025481  ...
# nullVotes                           -0.090835          0.400110  ...
# nullVotesPercentage                  1.000000         -0.214648  ...
# votersPercentage                    -0.214648          1.000000  ...
# subscribedVoters                    -0.223461          0.351045  ...
# totalVoters                         -0.217615          0.408169  ...
# pre.blankVotes                      -0.178846          0.387145  ...
# pre.blankVotesPercentage             0.143924          0.001029  ...
# pre.nullVotes                       -0.137261          0.354969  ...
# pre.nullVotesPercentage              0.665506         -0.426438  ...
# pre.votersPercentage                -0.349181          0.888275  ...
# pre.subscribedVoters                -0.211254          0.353829  ...
# pre.totalVoters                     -0.218489          0.406768  ...
# Percentage                          -0.024892         -0.023488  ...
# validVotesPercentage                -0.022716         -0.024374  ...
# Votes                               -0.126520          0.168028  ...
#
#                           pre.blankVotes  pre.blankVotesPercentage  \
# TimeElapsed                     0.557561                  0.108332
# totalMandates                   0.872799                  0.178681
# availableMandates               0.015406                 -0.011035
# numParishes                     0.437714                  0.313643
# numParishesApproved             0.680910                  0.250937
# blankVotes                      0.996520                  0.423201
# blankVotesPercentage            0.335073                  0.965773
# nullVotes                       0.971477                  0.217198
# nullVotesPercentage            -0.178846                  0.143924
# votersPercentage                0.387145                  0.001029
# subscribedVoters                0.973944                  0.222919
# totalVoters                     0.973310                  0.203447
# pre.blankVotes                  1.000000                  0.387629
# pre.blankVotesPercentage        0.387629                  1.000000
# pre.nullVotes                   0.954284                  0.171835
# pre.nullVotesPercentage        -0.240033                 -0.034611
# pre.votersPercentage            0.262871                 -0.093998
# pre.subscribedVoters            0.975894                  0.223928
# pre.totalVoters                 0.977422                  0.210681
# Percentage                     -0.006324                 -0.005694
# validVotesPercentage           -0.005687                 -0.001073
# Votes                           0.569056                  0.107967
#
#                           pre.nullVotes  pre.nullVotesPercentage  \
# TimeElapsed                    0.573367                -0.090531
# totalMandates                  0.882849                -0.204753
# availableMandates             -0.003521                -0.110033
# numParishes                    0.376188                 0.042485
# numParishesApproved            0.658002                 0.018030
# blankVotes                     0.932149                -0.279369
# blankVotesPercentage           0.119249                -0.071278
# nullVotes                      0.988773                -0.137423
# nullVotesPercentage           -0.137261                 0.665506
# votersPercentage               0.354969                -0.426438
# subscribedVoters               0.983859                -0.203593
# totalVoters                    0.984915                -0.214640
# pre.blankVotes                 0.954284                -0.240033
# pre.blankVotesPercentage       0.171835                -0.034611
# pre.nullVotes                  1.000000                -0.070410
# pre.nullVotesPercentage       -0.070410                 1.000000
# pre.votersPercentage           0.200519                -0.602399
# pre.subscribedVoters           0.985224                -0.199850
# pre.totalVoters                0.983139                -0.228062
# Percentage                    -0.003783                 0.001612
# validVotesPercentage          -0.004172                 0.002262
# Votes                          0.578732                -0.093736
#
#                           pre.votersPercentage  pre.subscribedVoters  \
# TimeElapsed                           0.061075              0.583511
# totalMandates                         0.212050              0.894533
# availableMandates                     0.203911             -0.012584
# numParishes                          -0.146604              0.390926
# numParishesApproved                  -0.147325              0.672559
# blankVotes                            0.279618              0.962679
# blankVotesPercentage                 -0.065960              0.177822
# nullVotes                             0.244706              0.987510
# nullVotesPercentage                  -0.349181             -0.211254
# votersPercentage                      0.888275              0.353829
# subscribedVoters                      0.217876              0.999607
# totalVoters                           0.273074              0.996974
# pre.blankVotes                        0.262871              0.975894
# pre.blankVotesPercentage             -0.093998              0.223928
# pre.nullVotes                         0.200519              0.985224
# pre.nullVotesPercentage              -0.602399             -0.199850
# pre.votersPercentage                  1.000000              0.217707
# pre.subscribedVoters                  0.217707              1.000000
# pre.totalVoters                       0.281614              0.997066
# Percentage                            0.006324             -0.005318
# validVotesPercentage                  0.005173             -0.005520
# Votes                                 0.123673              0.578458
#
#                           pre.totalVoters  Percentage  validVotesPercentage  \
# TimeElapsed                      0.579351    0.029081              0.029017
# totalMandates                    0.890323    0.004637              0.004310
# availableMandates               -0.001522   -0.024213             -0.024672
# numParishes                      0.373675   -0.070716             -0.068948
# numParishesApproved              0.655205   -0.043480             -0.042401
# blankVotes                       0.965080   -0.009146             -0.008258
# blankVotesPercentage             0.167995   -0.012564             -0.007818
# nullVotes                        0.988997   -0.010213             -0.010292
# nullVotesPercentage             -0.218489   -0.024892             -0.022716
# votersPercentage                 0.406768   -0.023488             -0.024374
# subscribedVoters                 0.996505   -0.003826             -0.004054
# totalVoters                      0.999317   -0.005410             -0.005742
# pre.blankVotes                   0.977422   -0.006324             -0.005687
# pre.blankVotesPercentage         0.210681   -0.005694             -0.001073
# pre.nullVotes                    0.983139   -0.003783             -0.004172
# pre.nullVotesPercentage         -0.228062    0.001612              0.002262
# pre.votersPercentage             0.281614    0.006324              0.005173
# pre.subscribedVoters             0.997066   -0.005318             -0.005520
# pre.totalVoters                  1.000000   -0.004751             -0.005026
# Percentage                      -0.004751    1.000000              0.999958
# validVotesPercentage            -0.005026    0.999958              1.000000
# Votes                            0.580193    0.765050              0.764875
#
#                              Votes
# TimeElapsed               0.380162
# totalMandates             0.526818
# availableMandates        -0.031009
# numParishes               0.186187
# numParishesApproved       0.391411
# blankVotes                0.556560
# blankVotesPercentage      0.073904
# nullVotes                 0.572321
# nullVotesPercentage      -0.126520
# votersPercentage          0.168028
# subscribedVoters          0.578755
# totalVoters               0.578555
# pre.blankVotes            0.569056
# pre.blankVotesPercentage  0.107967
# pre.nullVotes             0.578732
# pre.nullVotesPercentage  -0.093736
# pre.votersPercentage      0.123673
# pre.subscribedVoters      0.578458
# pre.totalVoters           0.580193
# Percentage                0.765050
# validVotesPercentage      0.764875
# Votes                     1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(27,23))
sns.heatmap(correlation,annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
#                                        FEATURE SELECTION
# Feature selection is a process used in machine learning and data analysis to identify the most relevant features in a dataset. it helps to improve model perfomance, reduces overfitting, and enhances interpretability

# %%
#FEATURE SELECTION
x=df2.drop('Votes',axis=1)
y=df2['Votes']

# %%
sk=SelectKBest(score_func=f_regression,k=19)
x_num=sk.fit_transform(x,y)

# %%
selected_features=x.columns[sk.get_support()]
feature_scores=pd.DataFrame({'feature':x.columns,'score':sk.scores_}).sort_values(by='score',ascending=False)

print("selected features:",selected_features)
print("\nfeature scores:")
print(feature_scores)
# Out:
# selected features: Index(['TimeElapsed', 'totalMandates', 'numParishes', 'numParishesApproved',
#        'blankVotes', 'nullVotes', 'nullVotesPercentage', 'votersPercentage',
#        'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Percentage', 'validVotesPercentage'],
#       dtype='object')
#
# feature scores:
#                      feature         score
# 19                Percentage  30543.830668
# 20      validVotesPercentage  30510.287552
# 18           pre.totalVoters  10981.518444
# 10          subscribedVoters  10899.780261
# 14             pre.nullVotes  10898.482295
# 11               totalVoters  10888.429776
# 17      pre.subscribedVoters  10882.985022
# 7                  nullVotes  10541.392558
# 12            pre.blankVotes  10364.028817
# 5                 blankVotes   9711.832787
# 1              totalMandates   8313.486537
# 4        numParishesApproved   3915.296465
# 0                TimeElapsed   3656.009056
# 3                numParishes    777.138676
# 9           votersPercentage    628.749905
# 8        nullVotesPercentage    352.051185
# 16      pre.votersPercentage    336.142721
# 13  pre.blankVotesPercentage    255.244009
# 15   pre.nullVotesPercentage    191.830787
# 6       blankVotesPercentage    118.849448
# 2          availableMandates     20.828637

# %%
x_selected=x[selected_features]

# %%
x_selected.columns
# Out:
# Index(['TimeElapsed', 'totalMandates', 'numParishes', 'numParishesApproved',
#        'blankVotes', 'nullVotes', 'nullVotesPercentage', 'votersPercentage',
#        'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Percentage', 'validVotesPercentage'],
#       dtype='object')

# %%
#SCALING
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x_selected)

# %%
#DATA SPLITTING
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
print(f"""
x train shape:{x_train.shape}
x test shape:{x_test.shape}
y train shape:{y_train.shape}
y test shape:{y_test.shape}
""")
# Out:
# x train shape:(17314, 19)
# x test shape:(4329, 19)
# y train shape:(17314,)
# y test shape:(4329,)

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)

# %%
#MODEL BUILDING - REGRESSION MODELS
models={
    '1.linear regression':LinearRegression(),
    '2.decision tree regressor':DecisionTreeRegressor(),
    '3.random forest regressor':RandomForestRegressor(),
    '4.gradient boosting regressor':GradientBoostingRegressor(),
    '5.svr':SVR()
}

# %%
#EVALUATION
result={}
for model_name,model in models.items():
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    mae=mean_absolute_error(y_test,y_pred)
    mse=mean_squared_error(y_test,y_pred)
    rmse=np.sqrt(mse)
    r2=r2_score(y_test,y_pred)
    result[model_name]={'mae':mae,'mse':mse,'rmse':rmse,'r2':r2}

# %%
result_df=pd.DataFrame(result).T
result_df
# Out:
#                                     mae       mse      rmse        r2
# 1.linear regression            0.152179  0.061222  0.247432  0.938653
# 2.decision tree regressor      0.022899  0.008190  0.090496  0.991794
# 3.random forest regressor      0.020904  0.006851  0.082770  0.993135
# 4.gradient boosting regressor  0.057071  0.007773  0.088164  0.992211
# 5.svr                          0.079807  0.015738  0.125453  0.984230

# %%
#BEST MODEL ESTIMATOR
best_model=result_df.sort_values(by='r2',ascending=False).iloc[0]
print('best_model',best_model)
# Out:
# best_model mae     0.020904
# mse     0.006851
# rmse    0.082770
# r2      0.993135
# Name: 3.random forest regressor, dtype: float64

# %%
#HYPERPARAMETER TUNING
rfg = RandomForestRegressor(
    random_state=42,
    n_estimators=50,         
    max_depth=10,             
    min_samples_split=5,      
    min_samples_leaf=2,       
    max_features='sqrt',      
    n_jobs=-1                
)

# %%
param_grid = {
    'n_estimators': [50, 100, 200,300],  
    'max_depth': [10, 20, None],     
    'min_samples_split': [2, 5, 10], 
    'min_samples_leaf': [1, 2, 4]   
}

# %%
grid_search = GridSearchCV(
    estimator=rfg,
    param_grid=param_grid,
    cv=10,  
    scoring='r2',  
    n_jobs=-1, 
    verbose=2   
)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# GridSearchCV(cv=10,
#              estimator=RandomForestRegressor(max_depth=10, max_features='sqrt',
#                                              min_samples_leaf=2,
#                                              min_samples_split=5,
#                                              n_estimators=50, n_jobs=-1,
#                                              random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [10, 20, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200, 300]},
#              scoring='r2', verbose=2)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best R² Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}
# Best R² Score: 0.9944033141747447

# %%
best_model=grid_search.best_estimator_
best_model.fit(x_train_scaled,y_train)

y_test_pred=best_model.predict(x_test_scaled)

test_mae=mean_absolute_error(y_test,y_test_pred)
test_mse=mean_squared_error(y_test,y_test_pred)
test_rmse=np.sqrt(mean_squared_error(y_test,y_test_pred))
test_r2=r2_score(y_test,y_test_pred)

print(f"test mae:{test_mae}")
print(f"test mse:{test_mse}")
print(f"test rmse:{test_rmse}")
print(f"test r2:{test_r2}")
# Out:
# test mae:0.047480584110845374
# test mse:0.010330888920139879
# test rmse:0.10164098051543914
# test r2:0.9896481047049871

# %%
y_train_pred=best_model.predict(x_train_scaled)
residuals=y_train-y_train_pred

# %%
#PIPELINE CREATION
from sklearn.pipeline import Pipeline

# %%
pipeline=Pipeline([
    ('scaler',StandardScaler()),
    ('model',RandomForestRegressor(random_state=42))
])

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', RandomForestRegressor(random_state=42))])

# %%
joblib.dump(pipeline,"rfr_pipeline.joblib")
# Out:
# ['rfr_pipeline.joblib']

# %%
loaded_pipeline=joblib.load('rfr_pipeline.joblib')

# %%
#PREDICTION 
unseen_data=pd.read_csv('Unseen.csv')

# %%
df_unseen=pd.DataFrame(unseen_data)

# %%
df_unseen.head()
# Out:
#    TimeElapsed  totalMandates  numParishes  numParishesApproved  blankVotes  \
# 0            0              0         3092                 1081        9652
# 1            0              0         3092                 1081        9652
# 2            0              0         3092                 1081        9652
# 3            0              0         3092                 1081        9652
# 4            0              0         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  nullVotesPercentage  votersPercentage  \
# 0                   2.5       8874                  2.3             51.36
# 1                   2.5       8874                  2.3             51.36
# 2                   2.5       8874                  2.3             51.36
# 3                   2.5       8874                  2.3             51.36
# 4                   2.5       8874                  2.3             51.36
#
#    subscribedVoters  totalVoters  pre.blankVotes  pre.blankVotesPercentage  \
# 0            752529       386497            8317                      1.94
# 1            752529       386497            8317                      1.94
# 2            752529       386497            8317                      1.94
# 3            752529       386497            8317                      1.94
# 4            752529       386497            8317                      1.94
#
#    pre.nullVotes  pre.nullVotesPercentage  pre.votersPercentage  \
# 0           8171                     1.91                 52.66
# 1           8171                     1.91                 52.66
# 2           8171                     1.91                 52.66
# 3           8171                     1.91                 52.66
# 4           8171                     1.91                 52.66
#
#    pre.subscribedVoters  pre.totalVoters  Percentage  validVotesPercentage
# 0                813743           428546       38.29                 40.22
# 1                813743           428546       33.28                 34.95
# 2                813743           428546        6.81                  7.15
# 3                813743           428546        4.90                  5.14
# 4                813743           428546        4.59                  4.83

# %%
df_unseen.shape
# Out:
# (21643, 20)

# %%
df_unseen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   totalMandates             21643 non-null  int64
#  2   numParishes               21643 non-null  int64
#  3   numParishesApproved       21643 non-null  int64
#  4   blankVotes                21643 non-null  int64
#  5   blankVotesPercentage      21643 non-null  float64
#  6   nullVotes                 21643 non-null  int64
#  7   nullVotesPercentage       21643 non-null  float64
#  8   votersPercentage          21643 non-null  float64
#  9   subscribedVoters          21643 non-null  int64
#  10  totalVoters               21643 non-null  int64
#  11  pre.blankVotes            21643 non-null  int64
#  12  pre.blankVotesPercentage  21643 non-null  float64
#  13  pre.nullVotes             21643 non-null  int64
#  14  pre.nullVotesPercentage   21643 non-null  float64
#  15  pre.votersPercentage      21643 non-null  float64
#  16  pre.subscribedVoters      21643 non-null  int64
#  17  pre.totalVoters           21643 non-null  int64
#  18  Percentage                21643 non-null  float64
#  19  validVotesPercentage      21643 non-null  float64
# dtypes: float64(8), int64(12)
# memory usage: 3.3 MB

# %%
x_unseen=df_unseen.drop('validVotesPercentage',axis=1)
y_unseen=df_unseen['validVotesPercentage']

# %%
y_pred_unseen=loaded_pipeline.predict(x_unseen)
# Out:
# C:\Users\ansar\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
unseen_mae=mean_absolute_error(y_unseen,y_pred_unseen)
unseen_mse=mean_squared_error(y_unseen,y_pred_unseen)
unseen_rmse=np.sqrt(mean_squared_error(y_unseen,y_pred_unseen))
unseen_r2=r2_score(y_unseen,y_pred_unseen)

print(f"unseen mae:{unseen_mae}")
print(f"unseen mse:{unseen_mse}")
print(f"unseen rmse:{unseen_rmse}")
print(f"unseen r2:{unseen_r2}")
# Out:
# unseen mae:5.085398240559847
# unseen mse:132.94578850172437
# unseen rmse:11.530211988585656
# unseen r2:-0.12291897068840574

# %%
df_unseen['predicted_election_result']=y_pred_unseen
df_unseen.to_csv('unseen_predictions.csv',index=False)
print("prediction saved to'unseen_prediction.csv'.")
# Out:
# prediction saved to'unseen_prediction.csv'.

# %%
predicted_df=pd.read_csv('unseen_predictions.csv')
predicted_df.head(50)
# Out:
#     TimeElapsed  totalMandates  numParishes  numParishesApproved  blankVotes  \
# 0             0              0         3092                 1081        9652
# 1             0              0         3092                 1081        9652
# 2             0              0         3092                 1081        9652
# 3             0              0         3092                 1081        9652
# 4             0              0         3092                 1081        9652
# 5             0              0         3092                 1081        9652
# 6             0              0         3092                 1081        9652
# 7             0              0         3092                 1081        9652
# 8             0              0         3092                 1081        9652
# 9             0              0         3092                 1081        9652
# 10            0              0         3092                 1081        9652
# 11            0              0         3092                 1081        9652
# 12            0              0         3092                 1081        9652
# 13            0              0         3092                 1081        9652
# 14            0              0         3092                 1081        9652
# 15            0              0         3092                 1081        9652
# 16            0              0         3092                 1081        9652
# 17            0              0         3092                 1081        9652
# 18            0              0         3092                 1081        9652
# 19            0              0         3092                 1081        9652
# 20            0              0         3092                 1081        9652
# 21            0              0          147                   12         186
# 22            0              0          147                   12         186
# 23            0              0          147                   12         186
# 24            0              0          147                   12         186
# 25            0              0          147                   12         186
# 26            0              0          147                   12         186
# 27            0              0          147                   12         186
# 28            0              0          147                   12         186
# 29            0              0          147                   12         186
# 30            0              0          147                   12         186
# 31            0              0          147                   12         186
# 32            0              0          147                   12         186
# 33            0              0          147                   12         186
# 34            0              0          147                   12         186
# 35            0              0          147                   12         186
# 36            0              0          147                   12         186
# 37            0              0          147                   12         186
# 38            0              0          147                   12         186
# 39            0              0          147                   12         186
# 40            0              0          147                   12         186
# 41            0              0           75                   23         125
# 42            0              0           75                   23         125
# 43            0              0           75                   23         125
# 44            0              0           75                   23         125
# 45            0              0           75                   23         125
# 46            0              0           75                   23         125
# 47            0              0           75                   23         125
# 48            0              0           75                   23         125
# 49            0              0           75                   23         125
#
#     blankVotesPercentage  nullVotes  nullVotesPercentage  votersPercentage  \
# 0                   2.50       8874                 2.30             51.36
# 1                   2.50       8874                 2.30             51.36
# 2                   2.50       8874                 2.30             51.36
# 3                   2.50       8874                 2.30             51.36
# 4                   2.50       8874                 2.30             51.36
# 5                   2.50       8874                 2.30             51.36
# 6                   2.50       8874                 2.30             51.36
# 7                   2.50       8874                 2.30             51.36
# 8                   2.50       8874                 2.30             51.36
# 9                   2.50       8874                 2.30             51.36
# 10                  2.50       8874                 2.30             51.36
# 11                  2.50       8874                 2.30             51.36
# 12                  2.50       8874                 2.30             51.36
# 13                  2.50       8874                 2.30             51.36
# 14                  2.50       8874                 2.30             51.36
# 15                  2.50       8874                 2.30             51.36
# 16                  2.50       8874                 2.30             51.36
# 17                  2.50       8874                 2.30             51.36
# 18                  2.50       8874                 2.30             51.36
# 19                  2.50       8874                 2.30             51.36
# 20                  2.50       8874                 2.30             51.36
# 21                  2.92        101                 1.59             53.30
# 22                  2.92        101                 1.59             53.30
# 23                  2.92        101                 1.59             53.30
# 24                  2.92        101                 1.59             53.30
# 25                  2.92        101                 1.59             53.30
# 26                  2.92        101                 1.59             53.30
# 27                  2.92        101                 1.59             53.30
# 28                  2.92        101                 1.59             53.30
# 29                  2.92        101                 1.59             53.30
# 30                  2.92        101                 1.59             53.30
# 31                  2.92        101                 1.59             53.30
# 32                  2.92        101                 1.59             53.30
# 33                  2.92        101                 1.59             53.30
# 34                  2.92        101                 1.59             53.30
# 35                  2.92        101                 1.59             53.30
# 36                  2.92        101                 1.59             53.30
# 37                  2.92        101                 1.59             53.30
# 38                  2.92        101                 1.59             53.30
# 39                  2.92        101                 1.59             53.30
# 40                  2.92        101                 1.59             53.30
# 41                  1.69        136                 1.84             52.24
# 42                  1.69        136                 1.84             52.24
# 43                  1.69        136                 1.84             52.24
# 44                  1.69        136                 1.84             52.24
# 45                  1.69        136                 1.84             52.24
# 46                  1.69        136                 1.84             52.24
# 47                  1.69        136                 1.84             52.24
# 48                  1.69        136                 1.84             52.24
# 49                  1.69        136                 1.84             52.24
#
#     subscribedVoters  ...  pre.blankVotes  pre.blankVotesPercentage  \
# 0             752529  ...            8317                      1.94
# 1             752529  ...            8317                      1.94
# 2             752529  ...            8317                      1.94
# 3             752529  ...            8317                      1.94
# 4             752529  ...            8317                      1.94
# 5             752529  ...            8317                      1.94
# 6             752529  ...            8317                      1.94
# 7             752529  ...            8317                      1.94
# 8             752529  ...            8317                      1.94
# 9             752529  ...            8317                      1.94
# 10            752529  ...            8317                      1.94
# 11            752529  ...            8317                      1.94
# 12            752529  ...            8317                      1.94
# 13            752529  ...            8317                      1.94
# 14            752529  ...            8317                      1.94
# 15            752529  ...            8317                      1.94
# 16            752529  ...            8317                      1.94
# 17            752529  ...            8317                      1.94
# 18            752529  ...            8317                      1.94
# 19            752529  ...            8317                      1.94
# 20            752529  ...            8317                      1.94
# 21             11953  ...             124                      1.82
# 22             11953  ...             124                      1.82
# 23             11953  ...             124                      1.82
# 24             11953  ...             124                      1.82
# 25             11953  ...             124                      1.82
# 26             11953  ...             124                      1.82
# 27             11953  ...             124                      1.82
# 28             11953  ...             124                      1.82
# 29             11953  ...             124                      1.82
# 30             11953  ...             124                      1.82
# 31             11953  ...             124                      1.82
# 32             11953  ...             124                      1.82
# 33             11953  ...             124                      1.82
# 34             11953  ...             124                      1.82
# 35             11953  ...             124                      1.82
# 36             11953  ...             124                      1.82
# 37             11953  ...             124                      1.82
# 38             11953  ...             124                      1.82
# 39             11953  ...             124                      1.82
# 40             11953  ...             124                      1.82
# 41             14136  ...             122                      1.37
# 42             14136  ...             122                      1.37
# 43             14136  ...             122                      1.37
# 44             14136  ...             122                      1.37
# 45             14136  ...             122                      1.37
# 46             14136  ...             122                      1.37
# 47             14136  ...             122                      1.37
# 48             14136  ...             122                      1.37
# 49             14136  ...             122                      1.37
#
#     pre.nullVotes  pre.nullVotesPercentage  pre.votersPercentage  \
# 0            8171                     1.91                 52.66
# 1            8171                     1.91                 52.66
# 2            8171                     1.91                 52.66
# 3            8171                     1.91                 52.66
# 4            8171                     1.91                 52.66
# 5            8171                     1.91                 52.66
# 6            8171                     1.91                 52.66
# 7            8171                     1.91                 52.66
# 8            8171                     1.91                 52.66
# 9            8171                     1.91                 52.66
# 10           8171                     1.91                 52.66
# 11           8171                     1.91                 52.66
# 12           8171                     1.91                 52.66
# 13           8171                     1.91                 52.66
# 14           8171                     1.91                 52.66
# 15           8171                     1.91                 52.66
# 16           8171                     1.91                 52.66
# 17           8171                     1.91                 52.66
# 18           8171                     1.91                 52.66
# 19           8171                     1.91                 52.66
# 20           8171                     1.91                 52.66
# 21            111                     1.63                 54.56
# 22            111                     1.63                 54.56
# 23            111                     1.63                 54.56
# 24            111                     1.63                 54.56
# 25            111                     1.63                 54.56
# 26            111                     1.63                 54.56
# 27            111                     1.63                 54.56
# 28            111                     1.63                 54.56
# 29            111                     1.63                 54.56
# 30            111                     1.63                 54.56
# 31            111                     1.63                 54.56
# 32            111                     1.63                 54.56
# 33            111                     1.63                 54.56
# 34            111                     1.63                 54.56
# 35            111                     1.63                 54.56
# 36            111                     1.63                 54.56
# 37            111                     1.63                 54.56
# 38            111                     1.63                 54.56
# 39            111                     1.63                 54.56
# 40            111                     1.63                 54.56
# 41            140                     1.57                 58.12
# 42            140                     1.57                 58.12
# 43            140                     1.57                 58.12
# 44            140                     1.57                 58.12
# 45            140                     1.57                 58.12
# 46            140                     1.57                 58.12
# 47            140                     1.57                 58.12
# 48            140                     1.57                 58.12
# 49            140                     1.57                 58.12
#
#     pre.subscribedVoters  pre.totalVoters  Percentage  validVotesPercentage  \
# 0                 813743           428546       38.29                 40.22
# 1                 813743           428546       33.28                 34.95
# 2                 813743           428546        6.81                  7.15
# 3                 813743           428546        4.90                  5.14
# 4                 813743           428546        4.59                  4.83
# 5                 813743           428546        1.76                  1.84
# 6                 813743           428546        0.95                  0.99
# 7                 813743           428546        0.88                  0.93
# 8                 813743           428546        0.66                  0.70
# 9                 813743           428546        0.48                  0.51
# 10                813743           428546        0.48                  0.51
# 11                813743           428546        0.44                  0.47
# 12                813743           428546        0.32                  0.34
# 13                813743           428546        0.21                  0.22
# 14                813743           428546        0.21                  0.22
# 15                813743           428546        0.21                  0.22
# 16                813743           428546        0.19                  0.20
# 17                813743           428546        0.18                  0.19
# 18                813743           428546        0.17                  0.17
# 19                813743           428546        0.17                  0.18
# 20                813743           428546        0.02                  0.03
# 21                 12511             6826       37.75                 39.53
# 22                 12511             6826       34.33                 35.95
# 23                 12511             6826        7.47                  7.82
# 24                 12511             6826        6.14                  6.43
# 25                 12511             6826        2.39                  2.50
# 26                 12511             6826        2.04                  2.14
# 27                 12511             6826        1.62                  1.69
# 28                 12511             6826        0.58                  0.61
# 29                 12511             6826        0.57                  0.59
# 30                 12511             6826        0.55                  0.58
# 31                 12511             6826        0.39                  0.41
# 32                 12511             6826        0.39                  0.41
# 33                 12511             6826        0.30                  0.31
# 34                 12511             6826        0.24                  0.25
# 35                 12511             6826        0.19                  0.20
# 36                 12511             6826        0.17                  0.18
# 37                 12511             6826        0.13                  0.13
# 38                 12511             6826        0.11                  0.12
# 39                 12511             6826        0.09                  0.10
# 40                 12511             6826        0.06                  0.07
# 41                 15357             8926       46.06                 47.75
# 42                 15357             8926       24.61                 25.51
# 43                 15357             8926       10.10                 10.47
# 44                 15357             8926        7.35                  7.62
# 45                 15357             8926        1.83                  1.90
# 46                 15357             8926        1.75                  1.81
# 47                 15357             8926        1.34                  1.39
# 48                 15357             8926        1.27                  1.32
# 49                 15357             8926        0.46                  0.48
#
#     predicted_election_result
# 0                    1.396988
# 1                    1.396988
# 2                    1.396988
# 3                    1.396988
# 4                    1.396988
# 5                    1.396988
# 6                    1.421001
# 7                    1.420238
# 8                    1.413721
# 9                    1.413721
# 10                   1.413721
# 11                   1.413721
# 12                   1.413721
# 13                   1.413721
# 14                   1.413721
# 15                   1.413721
# 16                   1.413721
# 17                   1.413721
# 18                   1.413721
# 19                   1.413721
# 20                   1.413721
# 21                   1.396988
# 22                   1.396988
# 23                   1.396988
# 24                   1.396988
# 25                   1.396988
# 26                   1.396988
# 27                   1.396988
# 28                   1.413721
# 29                   1.413721
# 30                   1.413721
# 31                   1.413721
# 32                   1.413721
# 33                   1.413721
# 34                   1.413721
# 35                   1.413721
# 36                   1.413721
# 37                   1.413721
# 38                   1.413721
# 39                   1.413721
# 40                   1.413721
# 41                   1.396988
# 42                   1.396988
# 43                   1.396988
# 44                   1.396988
# 45                   1.396988
# 46                   1.396988
# 47                   1.403589
# 48                   1.402720
# 49                   1.415247
#
# [50 rows x 21 columns]

# %%
predicted_df.tail(20)
# Out:
#        TimeElapsed  totalMandates  numParishes  numParishesApproved  \
# 21623          265              8          277                  277
# 21624          265              8          277                  277
# 21625          265              8          277                  277
# 21626          265              8          277                  277
# 21627          265              8          277                  277
# 21628          265              8          277                  277
# 21629          265              8          277                  277
# 21630          265              8          277                  277
# 21631          265              8          277                  277
# 21632          265              8          277                  277
# 21633          265              8          277                  277
# 21634          265              8          277                  277
# 21635          265              8          277                  277
# 21636          265              8          277                  277
# 21637          265              8          277                  277
# 21638          265              8          277                  277
# 21639          265              8          277                  277
# 21640          265              8          277                  277
# 21641          265              8          277                  277
# 21642          265              8          277                  277
#
#        blankVotes  blankVotesPercentage  nullVotes  nullVotesPercentage  \
# 21623        4995                  2.81       3700                 2.08
# 21624        4995                  2.81       3700                 2.08
# 21625        4995                  2.81       3700                 2.08
# 21626        4995                  2.81       3700                 2.08
# 21627        4995                  2.81       3700                 2.08
# 21628        4995                  2.81       3700                 2.08
# 21629        4995                  2.81       3700                 2.08
# 21630        4995                  2.81       3700                 2.08
# 21631        4995                  2.81       3700                 2.08
# 21632        4995                  2.81       3700                 2.08
# 21633        4995                  2.81       3700                 2.08
# 21634        4995                  2.81       3700                 2.08
# 21635        4995                  2.81       3700                 2.08
# 21636        4995                  2.81       3700                 2.08
# 21637        4995                  2.81       3700                 2.08
# 21638        4995                  2.81       3700                 2.08
# 21639        4995                  2.81       3700                 2.08
# 21640        4995                  2.81       3700                 2.08
# 21641        4995                  2.81       3700                 2.08
# 21642        4995                  2.81       3700                 2.08
#
#        votersPercentage  subscribedVoters  ...  pre.blankVotes  \
# 21623             51.04            348061  ...            4235
# 21624             51.04            348061  ...            4235
# 21625             51.04            348061  ...            4235
# 21626             51.04            348061  ...            4235
# 21627             51.04            348061  ...            4235
# 21628             51.04            348061  ...            4235
# 21629             51.04            348061  ...            4235
# 21630             51.04            348061  ...            4235
# 21631             51.04            348061  ...            4235
# 21632             51.04            348061  ...            4235
# 21633             51.04            348061  ...            4235
# 21634             51.04            348061  ...            4235
# 21635             51.04            348061  ...            4235
# 21636             51.04            348061  ...            4235
# 21637             51.04            348061  ...            4235
# 21638             51.04            348061  ...            4235
# 21639             51.04            348061  ...            4235
# 21640             51.04            348061  ...            4235
# 21641             51.04            348061  ...            4235
# 21642             51.04            348061  ...            4235
#
#        pre.blankVotesPercentage  pre.nullVotes  pre.nullVotesPercentage  \
# 21623                      2.22           3632                      1.9
# 21624                      2.22           3632                      1.9
# 21625                      2.22           3632                      1.9
# 21626                      2.22           3632                      1.9
# 21627                      2.22           3632                      1.9
# 21628                      2.22           3632                      1.9
# 21629                      2.22           3632                      1.9
# 21630                      2.22           3632                      1.9
# 21631                      2.22           3632                      1.9
# 21632                      2.22           3632                      1.9
# 21633                      2.22           3632                      1.9
# 21634                      2.22           3632                      1.9
# 21635                      2.22           3632                      1.9
# 21636                      2.22           3632                      1.9
# 21637                      2.22           3632                      1.9
# 21638                      2.22           3632                      1.9
# 21639                      2.22           3632                      1.9
# 21640                      2.22           3632                      1.9
# 21641                      2.22           3632                      1.9
# 21642                      2.22           3632                      1.9
#
#        pre.votersPercentage  pre.subscribedVoters  pre.totalVoters  \
# 21623                 51.28                371931           190712
# 21624                 51.28                371931           190712
# 21625                 51.28                371931           190712
# 21626                 51.28                371931           190712
# 21627                 51.28                371931           190712
# 21628                 51.28                371931           190712
# 21629                 51.28                371931           190712
# 21630                 51.28                371931           190712
# 21631                 51.28                371931           190712
# 21632                 51.28                371931           190712
# 21633                 51.28                371931           190712
# 21634                 51.28                371931           190712
# 21635                 51.28                371931           190712
# 21636                 51.28                371931           190712
# 21637                 51.28                371931           190712
# 21638                 51.28                371931           190712
# 21639                 51.28                371931           190712
# 21640                 51.28                371931           190712
# 21641                 51.28                371931           190712
# 21642                 51.28                371931           190712
#
#        Percentage  validVotesPercentage  predicted_election_result
# 21623       36.24                 38.10                   1.395138
# 21624       35.37                 37.19                   1.395138
# 21625        7.86                  8.26                   1.395138
# 21626        5.89                  6.19                   1.395138
# 21627        2.30                  2.42                   1.395138
# 21628        2.13                  2.24                   1.395138
# 21629        0.97                  1.02                   1.422625
# 21630        0.75                  0.79                   1.419696
# 21631        0.68                  0.72                   1.416876
# 21632        0.55                  0.58                   1.416876
# 21633        0.51                  0.53                   1.416876
# 21634        0.49                  0.52                   1.416876
# 21635        0.26                  0.27                   1.416876
# 21636        0.20                  0.21                   1.416876
# 21637        0.20                  0.21                   1.416876
# 21638        0.19                  0.20                   1.416876
# 21639        0.18                  0.19                   1.416876
# 21640        0.14                  0.15                   1.416876
# 21641        0.13                  0.14                   1.416876
# 21642        0.07                  0.07                   1.416876
#
# [20 rows x 21 columns]
