# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler
from sklearn.feature_selection import SelectKBest,f_classif
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('OnlineNewsPopularity.csv')

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# 0                   0.815385         4.0              2.0        1.0  ...
# 1                   0.791946         3.0              1.0        1.0  ...
# 2                   0.663866         3.0              1.0        1.0  ...
# 3                   0.665635         9.0              0.0        1.0  ...
# 4                   0.540890        19.0             19.0       20.0  ...
#
#     min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# 0                0.100000                     0.7               -0.350000
# 1                0.033333                     0.7               -0.118750
# 2                0.100000                     1.0               -0.466667
# 3                0.136364                     0.8               -0.369697
# 4                0.033333                     1.0               -0.220192
#
#     min_negative_polarity   max_negative_polarity   title_subjectivity  \
# 0                  -0.600               -0.200000             0.500000
# 1                  -0.125               -0.100000             0.000000
# 2                  -0.800               -0.133333             0.000000
# 3                  -0.600               -0.166667             0.000000
# 4                  -0.500               -0.050000             0.454545
#
#     title_sentiment_polarity   abs_title_subjectivity  \
# 0                  -0.187500                 0.000000
# 1                   0.000000                 0.500000
# 2                   0.000000                 0.500000
# 3                   0.000000                 0.500000
# 4                   0.136364                 0.045455
#
#     abs_title_sentiment_polarity   shares
# 0                       0.187500      593
# 1                       0.000000      711
# 2                       0.000000     1500
# 3                       0.000000     1200
# 4                       0.136364      505
#
# [5 rows x 61 columns]

# %%
df.tail()
# Out:
#                                                      url   timedelta  \
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...         8.0
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...         8.0
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...         8.0
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/         8.0
# 39643  http://mashable.com/2014/12/27/youtube-channel...         8.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 39639             11.0              346.0          0.529052
# 39640             12.0              328.0          0.696296
# 39641             10.0              442.0          0.516355
# 39642              6.0              682.0          0.539493
# 39643             10.0              157.0          0.701987
#
#         n_non_stop_words   n_non_stop_unique_tokens   num_hrefs  \
# 39639                1.0                   0.684783         9.0
# 39640                1.0                   0.885057         9.0
# 39641                1.0                   0.644128        24.0
# 39642                1.0                   0.692661        10.0
# 39643                1.0                   0.846154         1.0
#
#         num_self_hrefs   num_imgs  ...   min_positive_polarity  \
# 39639              7.0        1.0  ...                0.100000
# 39640              7.0        3.0  ...                0.136364
# 39641              1.0       12.0  ...                0.136364
# 39642              1.0        1.0  ...                0.062500
# 39643              1.0        0.0  ...                0.100000
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 39639                    0.75               -0.260000                    -0.5
# 39640                    0.70               -0.211111                    -0.4
# 39641                    0.50               -0.356439                    -0.8
# 39642                    0.50               -0.205246                    -0.5
# 39643                    0.50               -0.200000                    -0.2
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 39639               -0.125000             0.100000                   0.000000
# 39640               -0.100000             0.300000                   1.000000
# 39641               -0.166667             0.454545                   0.136364
# 39642               -0.012500             0.000000                   0.000000
# 39643               -0.200000             0.333333                   0.250000
#
#         abs_title_subjectivity   abs_title_sentiment_polarity   shares
# 39639                 0.400000                       0.000000     1800
# 39640                 0.200000                       1.000000     1900
# 39641                 0.045455                       0.136364     1900
# 39642                 0.500000                       0.000000     1100
# 39643                 0.166667                       0.250000     1300
#
# [5 rows x 61 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             39644 non-null  object
#  1    timedelta                      39644 non-null  float64
#  2    n_tokens_title                 39644 non-null  float64
#  3    n_tokens_content               39644 non-null  float64
#  4    n_unique_tokens                39644 non-null  float64
#  5    n_non_stop_words               39644 non-null  float64
#  6    n_non_stop_unique_tokens       39644 non-null  float64
#  7    num_hrefs                      39644 non-null  float64
#  8    num_self_hrefs                 39644 non-null  float64
#  9    num_imgs                       39644 non-null  float64
#  10   num_videos                     39644 non-null  float64
#  11   average_token_length           39644 non-null  float64
#  12   num_keywords                   39644 non-null  float64
#  13   data_channel_is_lifestyle      39644 non-null  float64
#  14   data_channel_is_entertainment  39644 non-null  float64
#  15   data_channel_is_bus            39644 non-null  float64
#  16   data_channel_is_socmed         39644 non-null  float64
#  17   data_channel_is_tech           39644 non-null  float64
#  18   data_channel_is_world          39644 non-null  float64
#  19   kw_min_min                     39644 non-null  float64
#  20   kw_max_min                     39644 non-null  float64
#  21   kw_avg_min                     39644 non-null  float64
#  22   kw_min_max                     39644 non-null  float64
#  23   kw_max_max                     39644 non-null  float64
#  24   kw_avg_max                     39644 non-null  float64
#  25   kw_min_avg                     39644 non-null  float64
#  26   kw_max_avg                     39644 non-null  float64
#  27   kw_avg_avg                     39644 non-null  float64
#  28   self_reference_min_shares      39644 non-null  float64
#  29   self_reference_max_shares      39644 non-null  float64
#  30   self_reference_avg_sharess     39644 non-null  float64
#  31   weekday_is_monday              39644 non-null  float64
#  32   weekday_is_tuesday             39644 non-null  float64
#  33   weekday_is_wednesday           39644 non-null  float64
#  34   weekday_is_thursday            39644 non-null  float64
#  35   weekday_is_friday              39644 non-null  float64
#  36   weekday_is_saturday            39644 non-null  float64
#  37   weekday_is_sunday              39644 non-null  float64
#  38   is_weekend                     39644 non-null  float64
#  39   LDA_00                         39644 non-null  float64
#  40   LDA_01                         39644 non-null  float64
#  41   LDA_02                         39644 non-null  float64
#  42   LDA_03                         39644 non-null  float64
#  43   LDA_04                         39644 non-null  float64
#  44   global_subjectivity            39644 non-null  float64
#  45   global_sentiment_polarity      39644 non-null  float64
#  46   global_rate_positive_words     39644 non-null  float64
#  47   global_rate_negative_words     39644 non-null  float64
#  48   rate_positive_words            39644 non-null  float64
#  49   rate_negative_words            39644 non-null  float64
#  50   avg_positive_polarity          39644 non-null  float64
#  51   min_positive_polarity          39644 non-null  float64
#  52   max_positive_polarity          39644 non-null  float64
#  53   avg_negative_polarity          39644 non-null  float64
#  54   min_negative_polarity          39644 non-null  float64
#  55   max_negative_polarity          39644 non-null  float64
#  56   title_subjectivity             39644 non-null  float64
#  57   title_sentiment_polarity       39644 non-null  float64
#  58   abs_title_subjectivity         39644 non-null  float64
#  59   abs_title_sentiment_polarity   39644 non-null  float64
#  60   shares                         39644 non-null  int64
# dtypes: float64(59), int64(1), object(1)
# memory usage: 18.5+ MB

# %%
df.describe()
# Out:
#           timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# count  39644.000000    39644.000000      39644.000000     39644.000000
# mean     354.530471       10.398749        546.514731         0.548216
# std      214.163767        2.114037        471.107508         3.520708
# min        8.000000        2.000000          0.000000         0.000000
# 25%      164.000000        9.000000        246.000000         0.470870
# 50%      339.000000       10.000000        409.000000         0.539226
# 75%      542.000000       12.000000        716.000000         0.608696
# max      731.000000       23.000000       8474.000000       701.000000
#
#        n_non_stop_words  n_non_stop_unique_tokens     num_hrefs  \
# count      39644.000000              39644.000000  39644.000000
# mean           0.996469                  0.689175     10.883690
# std            5.231231                  3.264816     11.332017
# min            0.000000                  0.000000      0.000000
# 25%            1.000000                  0.625739      4.000000
# 50%            1.000000                  0.690476      8.000000
# 75%            1.000000                  0.754630     14.000000
# max         1042.000000                650.000000    304.000000
#
#        num_self_hrefs      num_imgs    num_videos  ...  min_positive_polarity  \
# count    39644.000000  39644.000000  39644.000000  ...           39644.000000
# mean         3.293638      4.544143      1.249874  ...               0.095446
# std          3.855141      8.309434      4.107855  ...               0.071315
# min          0.000000      0.000000      0.000000  ...               0.000000
# 25%          1.000000      1.000000      0.000000  ...               0.050000
# 50%          3.000000      1.000000      0.000000  ...               0.100000
# 75%          4.000000      4.000000      1.000000  ...               0.100000
# max        116.000000    128.000000     91.000000  ...               1.000000
#
#        max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# count           39644.000000           39644.000000           39644.000000
# mean                0.756728              -0.259524              -0.521944
# std                 0.247786               0.127726               0.290290
# min                 0.000000              -1.000000              -1.000000
# 25%                 0.600000              -0.328383              -0.700000
# 50%                 0.800000              -0.253333              -0.500000
# 75%                 1.000000              -0.186905              -0.300000
# max                 1.000000               0.000000               0.000000
#
#        max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# count           39644.000000        39644.000000              39644.000000
# mean               -0.107500            0.282353                  0.071425
# std                 0.095373            0.324247                  0.265450
# min                -1.000000            0.000000                 -1.000000
# 25%                -0.125000            0.000000                  0.000000
# 50%                -0.100000            0.150000                  0.000000
# 75%                -0.050000            0.500000                  0.150000
# max                 0.000000            1.000000                  1.000000
#
#        abs_title_subjectivity  abs_title_sentiment_polarity         shares
# count            39644.000000                  39644.000000   39644.000000
# mean                 0.341843                      0.156064    3395.380184
# std                  0.188791                      0.226294   11626.950749
# min                  0.000000                      0.000000       1.000000
# 25%                  0.166667                      0.000000     946.000000
# 50%                  0.500000                      0.000000    1400.000000
# 75%                  0.500000                      0.250000    2800.000000
# max                  0.500000                      1.000000  843300.000000
#
# [8 rows x 60 columns]

# %%
df.shape
# Out:
# (39644, 61)

# %%
df.columns
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
#        ' LDA_03', ' LDA_04', ' global_subjectivity',
#        ' global_sentiment_polarity', ' global_rate_positive_words',
#        ' global_rate_negative_words', ' rate_positive_words',
#        ' rate_negative_words', ' avg_positive_polarity',
#        ' min_positive_polarity', ' max_positive_polarity',
#        ' avg_negative_polarity', ' min_negative_polarity',
#        ' max_negative_polarity', ' title_subjectivity',
#        ' title_sentiment_polarity', ' abs_title_subjectivity',
#        ' abs_title_sentiment_polarity', ' shares'],
#       dtype='object')

# %%
df.dtypes
# Out:
# url                               object
#  timedelta                       float64
#  n_tokens_title                  float64
#  n_tokens_content                float64
#  n_unique_tokens                 float64
#                                   ...
#  title_subjectivity              float64
#  title_sentiment_polarity        float64
#  abs_title_subjectivity          float64
#  abs_title_sentiment_polarity    float64
#  shares                            int64
# Length: 61, dtype: object

# %%
df.isnull().sum()
# Out:
# url                              0
#  timedelta                       0
#  n_tokens_title                  0
#  n_tokens_content                0
#  n_unique_tokens                 0
#                                 ..
#  title_subjectivity              0
#  title_sentiment_polarity        0
#  abs_title_subjectivity          0
#  abs_title_sentiment_polarity    0
#  shares                          0
# Length: 61, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(axis=1)
# Out:
#                                                      url   timedelta  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2      http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3      http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
# ...                                                  ...         ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...         8.0
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...         8.0
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...         8.0
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/         8.0
# 39643  http://mashable.com/2014/12/27/youtube-channel...         8.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 0                 12.0              219.0          0.663594
# 1                  9.0              255.0          0.604743
# 2                  9.0              211.0          0.575130
# 3                  9.0              531.0          0.503788
# 4                 13.0             1072.0          0.415646
# ...                ...                ...               ...
# 39639             11.0              346.0          0.529052
# 39640             12.0              328.0          0.696296
# 39641             10.0              442.0          0.516355
# 39642              6.0              682.0          0.539493
# 39643             10.0              157.0          0.701987
#
#         n_non_stop_words   n_non_stop_unique_tokens   num_hrefs  \
# 0                    1.0                   0.815385         4.0
# 1                    1.0                   0.791946         3.0
# 2                    1.0                   0.663866         3.0
# 3                    1.0                   0.665635         9.0
# 4                    1.0                   0.540890        19.0
# ...                  ...                        ...         ...
# 39639                1.0                   0.684783         9.0
# 39640                1.0                   0.885057         9.0
# 39641                1.0                   0.644128        24.0
# 39642                1.0                   0.692661        10.0
# 39643                1.0                   0.846154         1.0
#
#         num_self_hrefs   num_imgs  ...   min_positive_polarity  \
# 0                  2.0        1.0  ...                0.100000
# 1                  1.0        1.0  ...                0.033333
# 2                  1.0        1.0  ...                0.100000
# 3                  0.0        1.0  ...                0.136364
# 4                 19.0       20.0  ...                0.033333
# ...                ...        ...  ...                     ...
# 39639              7.0        1.0  ...                0.100000
# 39640              7.0        3.0  ...                0.136364
# 39641              1.0       12.0  ...                0.136364
# 39642              1.0        1.0  ...                0.062500
# 39643              1.0        0.0  ...                0.100000
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                        0.70               -0.350000                  -0.600
# 1                        0.70               -0.118750                  -0.125
# 2                        1.00               -0.466667                  -0.800
# 3                        0.80               -0.369697                  -0.600
# 4                        1.00               -0.220192                  -0.500
# ...                       ...                     ...                     ...
# 39639                    0.75               -0.260000                  -0.500
# 39640                    0.70               -0.211111                  -0.400
# 39641                    0.50               -0.356439                  -0.800
# 39642                    0.50               -0.205246                  -0.500
# 39643                    0.50               -0.200000                  -0.200
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0                   -0.200000             0.500000                  -0.187500
# 1                   -0.100000             0.000000                   0.000000
# 2                   -0.133333             0.000000                   0.000000
# 3                   -0.166667             0.000000                   0.000000
# 4                   -0.050000             0.454545                   0.136364
# ...                       ...                  ...                        ...
# 39639               -0.125000             0.100000                   0.000000
# 39640               -0.100000             0.300000                   1.000000
# 39641               -0.166667             0.454545                   0.136364
# 39642               -0.012500             0.000000                   0.000000
# 39643               -0.200000             0.333333                   0.250000
#
#         abs_title_subjectivity   abs_title_sentiment_polarity   shares
# 0                     0.000000                       0.187500      593
# 1                     0.500000                       0.000000      711
# 2                     0.500000                       0.000000     1500
# 3                     0.500000                       0.000000     1200
# 4                     0.045455                       0.136364      505
# ...                        ...                            ...      ...
# 39639                 0.400000                       0.000000     1800
# 39640                 0.200000                       1.000000     1900
# 39641                 0.045455                       0.136364     1900
# 39642                 0.500000                       0.000000     1100
# 39643                 0.166667                       0.250000     1300
#
# [39644 rows x 61 columns]

# %%
#Outliers

numerical_columns=df.select_dtypes(include=['number'])

# %%
numerical_columns
# Out:
#        timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0          731.0            12.0             219.0         0.663594
# 1          731.0             9.0             255.0         0.604743
# 2          731.0             9.0             211.0         0.575130
# 3          731.0             9.0             531.0         0.503788
# 4          731.0            13.0            1072.0         0.415646
# ...          ...             ...               ...              ...
# 39639        8.0            11.0             346.0         0.529052
# 39640        8.0            12.0             328.0         0.696296
# 39641        8.0            10.0             442.0         0.516355
# 39642        8.0             6.0             682.0         0.539493
# 39643        8.0            10.0             157.0         0.701987
#
#        n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 0                   1.0                  0.815385        4.0             2.0
# 1                   1.0                  0.791946        3.0             1.0
# 2                   1.0                  0.663866        3.0             1.0
# 3                   1.0                  0.665635        9.0             0.0
# 4                   1.0                  0.540890       19.0            19.0
# ...                 ...                       ...        ...             ...
# 39639               1.0                  0.684783        9.0             7.0
# 39640               1.0                  0.885057        9.0             7.0
# 39641               1.0                  0.644128       24.0             1.0
# 39642               1.0                  0.692661       10.0             1.0
# 39643               1.0                  0.846154        1.0             1.0
#
#        num_imgs  num_videos  ...  min_positive_polarity  \
# 0           1.0         0.0  ...               0.100000
# 1           1.0         0.0  ...               0.033333
# 2           1.0         0.0  ...               0.100000
# 3           1.0         0.0  ...               0.136364
# 4          20.0         0.0  ...               0.033333
# ...         ...         ...  ...                    ...
# 39639       1.0         1.0  ...               0.100000
# 39640       3.0        48.0  ...               0.136364
# 39641      12.0         1.0  ...               0.136364
# 39642       1.0         0.0  ...               0.062500
# 39643       0.0         2.0  ...               0.100000
#
#        max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# 0                       0.70              -0.350000                 -0.600
# 1                       0.70              -0.118750                 -0.125
# 2                       1.00              -0.466667                 -0.800
# 3                       0.80              -0.369697                 -0.600
# 4                       1.00              -0.220192                 -0.500
# ...                      ...                    ...                    ...
# 39639                   0.75              -0.260000                 -0.500
# 39640                   0.70              -0.211111                 -0.400
# 39641                   0.50              -0.356439                 -0.800
# 39642                   0.50              -0.205246                 -0.500
# 39643                   0.50              -0.200000                 -0.200
#
#        max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# 0                  -0.200000            0.500000                 -0.187500
# 1                  -0.100000            0.000000                  0.000000
# 2                  -0.133333            0.000000                  0.000000
# 3                  -0.166667            0.000000                  0.000000
# 4                  -0.050000            0.454545                  0.136364
# ...                      ...                 ...                       ...
# 39639              -0.125000            0.100000                  0.000000
# 39640              -0.100000            0.300000                  1.000000
# 39641              -0.166667            0.454545                  0.136364
# 39642              -0.012500            0.000000                  0.000000
# 39643              -0.200000            0.333333                  0.250000
#
#        abs_title_subjectivity  abs_title_sentiment_polarity  shares
# 0                    0.000000                      0.187500     593
# 1                    0.500000                      0.000000     711
# 2                    0.500000                      0.000000    1500
# 3                    0.500000                      0.000000    1200
# 4                    0.045455                      0.136364     505
# ...                       ...                           ...     ...
# 39639                0.400000                      0.000000    1800
# 39640                0.200000                      1.000000    1900
# 39641                0.045455                      0.136364    1900
# 39642                0.500000                      0.000000    1100
# 39643                0.166667                      0.250000    1300
#
# [39644 rows x 60 columns]

# %%
plt.figure(figsize=(12,10))
sns.boxplot(data)
# Out:
# <Axes: >

# %%
def outliers(df):
    for col in df.select_dtypes(include=['float64','int64']).columns:
        Q1=df[col].quantile(0.25)
        Q3=df[col].quantile(0.75)
        IQR=Q3-Q1
        Lower_bound=Q1-(1.5*IQR)
        Upper_bound=Q3+(1.5*IQR)


        df[col]=df[col].apply(lambda x:Lower_bound if x<Lower_bound else Upper_bound if x > Upper_bound else x)

    return df

# %%
df1=outliers(df)

# %%
plt.figure(figsize=(15,12))
sns.boxplot(df1)
# Out:
# <Axes: >

# %%
df1=df1.drop(columns=['url'])

# %%
df1.head()
# Out:
#    timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0      731.0            12.0             219.0         0.663594
# 1      731.0             9.0             255.0         0.604743
# 2      731.0             9.0             211.0         0.575130
# 3      731.0             9.0             531.0         0.503788
# 4      731.0            13.0            1072.0         0.415646
#
#    n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 0               1.0                  0.815385        4.0             2.0
# 1               1.0                  0.791946        3.0             1.0
# 2               1.0                  0.663866        3.0             1.0
# 3               1.0                  0.665635        9.0             0.0
# 4               1.0                  0.540890       19.0             8.5
#
#    num_imgs  num_videos  ...  min_positive_polarity  max_positive_polarity  \
# 0       1.0         0.0  ...               0.100000                    0.7
# 1       1.0         0.0  ...               0.033333                    0.7
# 2       1.0         0.0  ...               0.100000                    1.0
# 3       1.0         0.0  ...               0.136364                    0.8
# 4       8.5         0.0  ...               0.033333                    1.0
#
#    avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# 0              -0.350000                 -0.600              -0.200000
# 1              -0.118750                 -0.125              -0.100000
# 2              -0.466667                 -0.800              -0.133333
# 3              -0.369697                 -0.600              -0.166667
# 4              -0.220192                 -0.500              -0.050000
#
#    title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# 0            0.500000                 -0.187500                0.000000
# 1            0.000000                  0.000000                0.500000
# 2            0.000000                  0.000000                0.500000
# 3            0.000000                  0.000000                0.500000
# 4            0.454545                  0.136364                0.045455
#
#    abs_title_sentiment_polarity  shares
# 0                      0.187500   593.0
# 1                      0.000000   711.0
# 2                      0.000000  1500.0
# 3                      0.000000  1200.0
# 4                      0.136364   505.0
#
# [5 rows x 60 columns]

# %%
pt=PowerTransformer(method='yeo-johnson')

# %%
numerical_features=df1.select_dtypes(include=['float64','int64']).columns

# %%
df1[numerical_features]=pt.fit_transform(df1[numerical_features])
# Out:
# ---------------------------------------------------------------------------
# BracketError                              Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df1[numerical_features]=pt.fit_transform(df1[numerical_features])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:3242, in PowerTransformer.fit_transform(self, X, y)
#    3224 @_fit_context(prefer_skip_nested_validation=True)
#    3225 def fit_transform(self, X, y=None):
#    3226     """Fit `PowerTransformer` to `X`, then transform `X`.
#    3227
#    3228     Parameters
#    (...)
#    3240         Transformed data.
#    3241     """
# -> 3242     return self._fit(X, y, force_transform=True)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:3274, in PowerTransformer._fit(self, X, y, force_transform)
#    3271     self.lambdas_[i] = 1.0
#    3272     continue
# -> 3274 self.lambdas_[i] = optim_function(col)
#    3276 if self.standardize or force_transform:
#    3277     X[:, i] = transform_function(X[:, i], self.lambdas_[i])
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:3463, in PowerTransformer._yeo_johnson_optimize(self, x)
#    3461 x = x[~np.isnan(x)]
#    3462 # choosing bracket -2, 2 like for boxcox
# -> 3463 return optimize.brent(_neg_log_likelihood, brack=(-2, 2))
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_optimize.py:2626, in brent(func, args, brack, tol, full_output, maxiter)
#    2554 """
#    2555 Given a function of one variable and a possible bracket, return
#    2556 a local minimizer of the function isolated to a fractional precision
#    (...)
#    2622
#    2623 """
#    2624 options = {'xtol': tol,
#    2625            'maxiter': maxiter}
# -> 2626 res = _minimize_scalar_brent(func, brack, args, **options)
#    2627 if full_output:
#    2628     return res['x'], res['fun'], res['nit'], res['nfev']
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_optimize.py:2663, in _minimize_scalar_brent(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2660 brent = Brent(func=func, args=args, tol=tol,
#    2661               full_output=True, maxiter=maxiter, disp=disp)
#    2662 brent.set_bracket(brack)
# -> 2663 brent.optimize()
#    2664 x, fval, nit, nfev = brent.get_result(full_output=True)
#    2666 success = nit < maxiter and not (np.isnan(x) or np.isnan(fval))
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_optimize.py:2433, in Brent.optimize(self)
#    2430 def optimize(self):
#    2431     # set up for optimization
#    2432     func = self.func
# -> 2433     xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#    2434     _mintol = self._mintol
#    2435     _cg = self._cg
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_optimize.py:2402, in Brent.get_bracket_info(self)
#    2400     xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#    2401 elif len(brack) == 2:
# -> 2402     xa, xb, xc, fa, fb, fc, funcalls = bracket(func, xa=brack[0],
#    2403                                                xb=brack[1], args=args)
#    2404 elif len(brack) == 3:
#    2405     xa, xb, xc = brack
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_optimize.py:3032, in bracket(func, xa, xb, args, grow_limit, maxiter)
#    3030     e = BracketError(msg)
#    3031     e.data = (xa, xb, xc, fa, fb, fc, funcalls)
# -> 3032     raise e
#    3034 return xa, xb, xc, fa, fb, fc, funcalls
#
# BracketError: The algorithm terminated without finding a valid bracket. Consider trying different initial points.

# %%
df1[numerical_features].skew()
# Out:
# timedelta                        0.120504
# n_tokens_title                   0.136293
# n_tokens_content                 0.983430
# n_unique_tokens                 -0.151793
# n_non_stop_words                 0.000000
# n_non_stop_unique_tokens        -0.284937
# num_hrefs                        1.095150
# num_self_hrefs                   0.817203
# num_imgs                         1.089328
# num_videos                       1.303549
# average_token_length            -0.125864
# num_keywords                    -0.138796
# data_channel_is_lifestyle        0.000000
# data_channel_is_entertainment    0.000000
# data_channel_is_bus              0.000000
# data_channel_is_socmed           0.000000
# data_channel_is_tech             0.000000
# data_channel_is_world            0.000000
# kw_min_min                       1.261410
# kw_max_min                       0.783821
# kw_avg_min                       0.801512
# kw_min_max                       1.197249
# kw_max_max                       0.000000
# kw_avg_max                       0.360348
# kw_min_avg                       0.467976
# kw_max_avg                       1.015306
# kw_avg_avg                       0.709141
# self_reference_min_shares        1.023338
# self_reference_max_shares        1.154731
# self_reference_avg_sharess       1.107288
# weekday_is_monday                0.000000
# weekday_is_tuesday               0.000000
# weekday_is_wednesday             0.000000
# weekday_is_thursday              0.000000
# weekday_is_friday                0.000000
# weekday_is_saturday              0.000000
# weekday_is_sunday                0.000000
# is_weekend                       0.000000
# LDA_00                           1.221184
# LDA_01                           1.270250
# LDA_02                           1.224886
# LDA_03                           1.234362
# LDA_04                           1.173129
# global_subjectivity             -0.200008
# global_sentiment_polarity        0.074485
# global_rate_positive_words       0.079433
# global_rate_negative_words       0.518768
# rate_positive_words             -0.509690
# rate_negative_words              0.229915
# avg_positive_polarity           -0.134310
# min_positive_polarity            0.212634
# max_positive_polarity           -0.939756
# avg_negative_polarity            0.004681
# min_negative_polarity           -0.073155
# max_negative_polarity           -0.627064
# title_subjectivity               0.816085
# title_sentiment_polarity         0.536174
# abs_title_subjectivity          -0.624149
# abs_title_sentiment_polarity     1.165508
# shares                           1.156802
# dtype: float64

# %%
df2=df1[numerical_features]

# %%
correlation=df2.corr()
correlation
# Out:
#                                timedelta  n_tokens_title  n_tokens_content  \
# timedelta                       1.000000       -0.240511         -0.071677
# n_tokens_title                 -0.240511        1.000000          0.013099
# n_tokens_content               -0.071677        0.013099          1.000000
# n_unique_tokens                 0.185444       -0.043285         -0.607885
# n_non_stop_words               -0.058914        0.004242          0.808889
# n_non_stop_unique_tokens        0.162944       -0.032750         -0.462322
# num_hrefs                       0.006225       -0.060418          0.458565
# num_self_hrefs                  0.054871        0.008974          0.273215
# num_imgs                       -0.065857       -0.024270          0.295300
# num_videos                     -0.113185        0.104124          0.029072
# average_token_length            0.022771       -0.100567          0.052961
# num_keywords                    0.047047       -0.006482          0.076055
# data_channel_is_lifestyle            NaN             NaN               NaN
# data_channel_is_entertainment        NaN             NaN               NaN
# data_channel_is_bus                  NaN             NaN               NaN
# data_channel_is_socmed               NaN             NaN               NaN
# data_channel_is_tech                 NaN             NaN               NaN
# data_channel_is_world                NaN             NaN               NaN
# kw_min_min                      0.849748       -0.188716         -0.080370
# kw_max_min                      0.128880       -0.057351          0.036479
# kw_avg_min                      0.425378       -0.119206          0.012993
# kw_min_max                     -0.164111        0.014476         -0.016932
# kw_max_max                           NaN             NaN               NaN
# kw_avg_max                     -0.507704        0.118550         -0.106899
# kw_min_avg                     -0.157204       -0.002194         -0.033665
# kw_max_avg                     -0.124522       -0.005880         -0.087602
# kw_avg_avg                     -0.203018       -0.001216         -0.116816
# self_reference_min_shares      -0.044857       -0.013819         -0.092357
# self_reference_max_shares      -0.039602        0.006617          0.087406
# self_reference_avg_sharess     -0.047449        0.001284          0.007324
# weekday_is_monday                    NaN             NaN               NaN
# weekday_is_tuesday                   NaN             NaN               NaN
# weekday_is_wednesday                 NaN             NaN               NaN
# weekday_is_thursday                  NaN             NaN               NaN
# weekday_is_friday                    NaN             NaN               NaN
# weekday_is_saturday                  NaN             NaN               NaN
# weekday_is_sunday                    NaN             NaN               NaN
# is_weekend                           NaN             NaN               NaN
# LDA_00                          0.084543       -0.070356          0.022776
# LDA_01                          0.008421        0.057878         -0.022814
# LDA_02                         -0.145167        0.039229          0.107499
# LDA_03                         -0.030776        0.042699         -0.166260
# LDA_04                          0.092906       -0.065609          0.044431
# global_subjectivity             0.102570       -0.052124          0.090624
# global_sentiment_polarity       0.165233       -0.073437          0.023424
# global_rate_positive_words      0.209316       -0.064621          0.161712
# global_rate_negative_words      0.002963        0.015162          0.172371
# rate_positive_words             0.186798       -0.066118          0.057966
# rate_negative_words            -0.074090        0.035495          0.133690
# avg_positive_polarity           0.106182       -0.045253          0.120712
# min_positive_polarity           0.069798       -0.008393         -0.306366
# max_positive_polarity           0.098288       -0.021969          0.468616
# avg_negative_polarity           0.000013       -0.019437         -0.180180
# min_negative_polarity           0.062175       -0.029130         -0.496784
# max_negative_polarity          -0.078181        0.012721          0.265855
# title_subjectivity             -0.015919        0.077242         -0.001568
# title_sentiment_polarity        0.040506        0.012936          0.010093
# abs_title_subjectivity          0.011551       -0.147044          0.012917
# abs_title_sentiment_polarity   -0.003452        0.052412          0.008699
# shares                          0.030760       -0.029364          0.015086
#
#                                n_unique_tokens  n_non_stop_words  \
# timedelta                             0.185444         -0.058914
# n_tokens_title                       -0.043285          0.004242
# n_tokens_content                     -0.607885          0.808889
# n_unique_tokens                       1.000000         -0.512913
# n_non_stop_words                     -0.512913          1.000000
# n_non_stop_unique_tokens              0.906946         -0.401149
# num_hrefs                            -0.211615          0.481131
# num_self_hrefs                       -0.078050          0.260364
# num_imgs                             -0.295235          0.291558
# num_videos                            0.047855         -0.017662
# average_token_length                  0.244225          0.233641
# num_keywords                         -0.087295          0.061977
# data_channel_is_lifestyle                  NaN               NaN
# data_channel_is_entertainment              NaN               NaN
# data_channel_is_bus                        NaN               NaN
# data_channel_is_socmed                     NaN               NaN
# data_channel_is_tech                       NaN               NaN
# data_channel_is_world                      NaN               NaN
# kw_min_min                            0.148411         -0.072353
# kw_max_min                           -0.035215          0.027454
# kw_avg_min                            0.015277          0.011479
# kw_min_max                           -0.003963         -0.040964
# kw_max_max                                 NaN               NaN
# kw_avg_max                            0.012449         -0.126309
# kw_min_avg                           -0.007133         -0.065883
# kw_max_avg                            0.012595         -0.102834
# kw_avg_avg                            0.016104         -0.157859
# self_reference_min_shares             0.166865         -0.044157
# self_reference_max_shares             0.044926          0.100942
# self_reference_avg_sharess            0.103573          0.041497
# weekday_is_monday                          NaN               NaN
# weekday_is_tuesday                         NaN               NaN
# weekday_is_wednesday                       NaN               NaN
# weekday_is_thursday                        NaN               NaN
# weekday_is_friday                          NaN               NaN
# weekday_is_saturday                        NaN               NaN
# weekday_is_sunday                          NaN               NaN
# is_weekend                                 NaN               NaN
# LDA_00                                0.021386          0.022564
# LDA_01                                0.073960         -0.050649
# LDA_02                               -0.103032          0.156699
# LDA_03                                0.078162         -0.186635
# LDA_04                               -0.043260          0.040422
# global_subjectivity                   0.228093          0.137627
# global_sentiment_polarity             0.121874          0.026797
# global_rate_positive_words            0.193091          0.143065
# global_rate_negative_words            0.113180          0.194885
# rate_positive_words                   0.212661          0.102393
# rate_negative_words                   0.115037          0.215721
# avg_positive_polarity                 0.209717          0.158114
# min_positive_polarity                 0.464945         -0.232349
# max_positive_polarity                -0.014938          0.519788
# avg_negative_polarity                -0.126406         -0.265734
# min_negative_polarity                 0.153575         -0.507125
# max_negative_polarity                -0.378397          0.154978
# title_subjectivity                    0.002624         -0.024744
# title_sentiment_polarity             -0.024668          0.007683
# abs_title_subjectivity               -0.012172          0.035091
# abs_title_sentiment_polarity         -0.011069         -0.009165
# shares                               -0.035034         -0.017310
#
#                                n_non_stop_unique_tokens  num_hrefs  \
# timedelta                                      0.162944   0.006225
# n_tokens_title                                -0.032750  -0.060418
# n_tokens_content                              -0.462322   0.458565
# n_unique_tokens                                0.906946  -0.211615
# n_non_stop_words                              -0.401149   0.481131
# n_non_stop_unique_tokens                       1.000000  -0.273158
# num_hrefs                                     -0.273158   1.000000
# num_self_hrefs                                -0.097036   0.350339
# num_imgs                                      -0.413427   0.382958
# num_videos                                     0.038238   0.030796
# average_token_length                           0.128254   0.273204
# num_keywords                                  -0.097626   0.158295
# data_channel_is_lifestyle                           NaN        NaN
# data_channel_is_entertainment                       NaN        NaN
# data_channel_is_bus                                 NaN        NaN
# data_channel_is_socmed                              NaN        NaN
# data_channel_is_tech                                NaN        NaN
# data_channel_is_world                               NaN        NaN
# kw_min_min                                     0.136138  -0.032248
# kw_max_min                                    -0.023852   0.061972
# kw_avg_min                                     0.023751   0.029467
# kw_min_max                                    -0.035663   0.037857
# kw_max_max                                          NaN        NaN
# kw_avg_max                                    -0.024789  -0.022069
# kw_min_avg                                    -0.045969   0.054557
# kw_max_avg                                    -0.060883   0.158532
# kw_avg_avg                                    -0.073912   0.150675
# self_reference_min_shares                      0.112023   0.020599
# self_reference_max_shares                      0.001946   0.204499
# self_reference_avg_sharess                     0.051149   0.136219
# weekday_is_monday                                   NaN        NaN
# weekday_is_tuesday                                  NaN        NaN
# weekday_is_wednesday                                NaN        NaN
# weekday_is_thursday                                 NaN        NaN
# weekday_is_friday                                   NaN        NaN
# weekday_is_saturday                                 NaN        NaN
# weekday_is_sunday                                   NaN        NaN
# is_weekend                                          NaN        NaN
# LDA_00                                         0.070849  -0.020050
# LDA_01                                         0.060674  -0.062594
# LDA_02                                        -0.048396  -0.018610
# LDA_03                                        -0.051674   0.130473
# LDA_04                                        -0.005011  -0.045315
# global_subjectivity                            0.189922   0.219505
# global_sentiment_polarity                      0.095002   0.114334
# global_rate_positive_words                     0.221861   0.091451
# global_rate_negative_words                     0.150876   0.059169
# rate_positive_words                            0.193386   0.094785
# rate_negative_words                            0.124382   0.076827
# avg_positive_polarity                          0.185154   0.209635
# min_positive_polarity                          0.356480  -0.084076
# max_positive_polarity                          0.032855   0.343953
# avg_negative_polarity                         -0.127293  -0.203549
# min_negative_polarity                          0.073271  -0.306100
# max_negative_polarity                         -0.286295   0.041098
# title_subjectivity                            -0.023226   0.046263
# title_sentiment_polarity                      -0.043463   0.039624
# abs_title_subjectivity                         0.001376   0.007502
# abs_title_sentiment_polarity                  -0.035555   0.062467
# shares                                        -0.057994   0.103244
#
#                                num_self_hrefs  num_imgs  num_videos  ...  \
# timedelta                            0.054871 -0.065857   -0.113185  ...
# n_tokens_title                       0.008974 -0.024270    0.104124  ...
# n_tokens_content                     0.273215  0.295300    0.029072  ...
# n_unique_tokens                     -0.078050 -0.295235    0.047855  ...
# n_non_stop_words                     0.260364  0.291558   -0.017662  ...
# n_non_stop_unique_tokens            -0.097036 -0.413427    0.038238  ...
# num_hrefs                            0.350339  0.382958    0.030796  ...
# num_self_hrefs                       1.000000  0.214892    0.076903  ...
# num_imgs                             0.214892  1.000000   -0.081589  ...
# num_videos                           0.076903 -0.081589    1.000000  ...
# average_token_length                 0.032693  0.039958   -0.126389  ...
# num_keywords                         0.096845  0.136073    0.015931  ...
# data_channel_is_lifestyle                 NaN       NaN         NaN  ...
# data_channel_is_entertainment             NaN       NaN         NaN  ...
# data_channel_is_bus                       NaN       NaN         NaN  ...
# data_channel_is_socmed                    NaN       NaN         NaN  ...
# data_channel_is_tech                      NaN       NaN         NaN  ...
# data_channel_is_world                     NaN       NaN         NaN  ...
# kw_min_min                          -0.002995 -0.086603   -0.094757  ...
# kw_max_min                           0.005000  0.022342   -0.028886  ...
# kw_avg_min                          -0.002491 -0.011157   -0.078161  ...
# kw_min_max                           0.041167  0.064801    0.079384  ...
# kw_max_max                                NaN       NaN         NaN  ...
# kw_avg_max                          -0.040049 -0.007705    0.213632  ...
# kw_min_avg                           0.050718  0.088544    0.074780  ...
# kw_max_avg                          -0.047302  0.200047    0.158423  ...
# kw_avg_avg                          -0.019389  0.218362    0.196943  ...
# self_reference_min_shares            0.008811  0.107600    0.034411  ...
# self_reference_max_shares            0.372072  0.197262    0.121467  ...
# self_reference_avg_sharess           0.227025  0.169307    0.105084  ...
# weekday_is_monday                         NaN       NaN         NaN  ...
# weekday_is_tuesday                        NaN       NaN         NaN  ...
# weekday_is_wednesday                      NaN       NaN         NaN  ...
# weekday_is_thursday                       NaN       NaN         NaN  ...
# weekday_is_friday                         NaN       NaN         NaN  ...
# weekday_is_saturday                       NaN       NaN         NaN  ...
# weekday_is_sunday                         NaN       NaN         NaN  ...
# is_weekend                                NaN       NaN         NaN  ...
# LDA_00                              -0.020651 -0.170480   -0.134164  ...
# LDA_01                               0.011832  0.043282    0.059031  ...
# LDA_02                              -0.107473 -0.116070   -0.086285  ...
# LDA_03                              -0.022396  0.213407    0.316179  ...
# LDA_04                               0.149679  0.023342   -0.154704  ...
# global_subjectivity                  0.102492  0.157185    0.079533  ...
# global_sentiment_polarity            0.103462  0.066938   -0.030691  ...
# global_rate_positive_words           0.134489  0.007862    0.019722  ...
# global_rate_negative_words           0.024294  0.029819    0.086907  ...
# rate_positive_words                  0.151094  0.001881   -0.069613  ...
# rate_negative_words                  0.015289  0.030430    0.038357  ...
# avg_positive_polarity                0.105721  0.139860    0.063013  ...
# min_positive_polarity               -0.045954 -0.017414    0.012787  ...
# max_positive_polarity                0.210310  0.195293    0.050907  ...
# avg_negative_polarity               -0.094034 -0.105172   -0.095233  ...
# min_negative_polarity               -0.126541 -0.165249   -0.092318  ...
# max_negative_polarity               -0.004704  0.043456    0.008773  ...
# title_subjectivity                  -0.019890  0.069984    0.068546  ...
# title_sentiment_polarity             0.020374  0.054467    0.013867  ...
# abs_title_subjectivity               0.013029 -0.014825   -0.017745  ...
# abs_title_sentiment_polarity        -0.014513  0.078360    0.057985  ...
# shares                               0.017866  0.112764    0.058826  ...
#
#                                min_positive_polarity  max_positive_polarity  \
# timedelta                                   0.069798               0.098288
# n_tokens_title                             -0.008393              -0.021969
# n_tokens_content                           -0.306366               0.468616
# n_unique_tokens                             0.464945              -0.014938
# n_non_stop_words                           -0.232349               0.519788
# n_non_stop_unique_tokens                    0.356480               0.032855
# num_hrefs                                  -0.084076               0.343953
# num_self_hrefs                             -0.045954               0.210310
# num_imgs                                   -0.017414               0.195293
# num_videos                                  0.012787               0.050907
# average_token_length                        0.125866               0.138252
# num_keywords                               -0.010464               0.062518
# data_channel_is_lifestyle                        NaN                    NaN
# data_channel_is_entertainment                    NaN                    NaN
# data_channel_is_bus                              NaN                    NaN
# data_channel_is_socmed                           NaN                    NaN
# data_channel_is_tech                             NaN                    NaN
# data_channel_is_world                            NaN                    NaN
# kw_min_min                                  0.047174               0.054571
# kw_max_min                                 -0.009150               0.042829
# kw_avg_min                                  0.002035               0.062236
# kw_min_max                                 -0.015839              -0.009662
# kw_max_max                                       NaN                    NaN
# kw_avg_max                                 -0.014887              -0.095292
# kw_min_avg                                 -0.010054              -0.012181
# kw_max_avg                                  0.041628               0.007729
# kw_avg_avg                                  0.031207              -0.007290
# self_reference_min_shares                   0.133617               0.082567
# self_reference_max_shares                   0.035198               0.151157
# self_reference_avg_sharess                  0.078428               0.128661
# weekday_is_monday                                NaN                    NaN
# weekday_is_tuesday                               NaN                    NaN
# weekday_is_wednesday                             NaN                    NaN
# weekday_is_thursday                              NaN                    NaN
# weekday_is_friday                                NaN                    NaN
# weekday_is_saturday                              NaN                    NaN
# weekday_is_sunday                                NaN                    NaN
# is_weekend                                       NaN                    NaN
# LDA_00                                     -0.132245               0.046285
# LDA_01                                      0.046624               0.038525
# LDA_02                                     -0.054611              -0.110093
# LDA_03                                      0.086188              -0.014090
# LDA_04                                      0.056448               0.042008
# global_subjectivity                         0.248014               0.424687
# global_sentiment_polarity                   0.117049               0.438902
# global_rate_positive_words                 -0.041013               0.485106
# global_rate_negative_words                  0.084277               0.203392
# rate_positive_words                         0.066638               0.355680
# rate_negative_words                         0.194913               0.047285
# avg_positive_polarity                       0.404705               0.666558
# min_positive_polarity                       1.000000               0.054085
# max_positive_polarity                       0.054085               1.000000
# avg_negative_polarity                      -0.092627              -0.289923
# min_negative_polarity                       0.072934              -0.360871
# max_negative_polarity                      -0.242526              -0.036412
# title_subjectivity                          0.013970               0.052790
# title_sentiment_polarity                   -0.002226               0.069879
# abs_title_subjectivity                      0.004159              -0.017131
# abs_title_sentiment_polarity                0.009505               0.076450
# shares                                     -0.026570               0.033658
#
#                                avg_negative_polarity  min_negative_polarity  \
# timedelta                                   0.000013               0.062175
# n_tokens_title                             -0.019437              -0.029130
# n_tokens_content                           -0.180180              -0.496784
# n_unique_tokens                            -0.126406               0.153575
# n_non_stop_words                           -0.265734              -0.507125
# n_non_stop_unique_tokens                   -0.127293               0.073271
# num_hrefs                                  -0.203549              -0.306100
# num_self_hrefs                             -0.094034              -0.126541
# num_imgs                                   -0.105172              -0.165249
# num_videos                                 -0.095233              -0.092318
# average_token_length                       -0.130047              -0.088386
# num_keywords                                0.020939              -0.002667
# data_channel_is_lifestyle                        NaN                    NaN
# data_channel_is_entertainment                    NaN                    NaN
# data_channel_is_bus                              NaN                    NaN
# data_channel_is_socmed                           NaN                    NaN
# data_channel_is_tech                             NaN                    NaN
# data_channel_is_world                            NaN                    NaN
# kw_min_min                                  0.017426               0.068056
# kw_max_min                                  0.014481              -0.001956
# kw_avg_min                                  0.015106               0.013935
# kw_min_max                                 -0.037044              -0.025387
# kw_max_max                                       NaN                    NaN
# kw_avg_max                                 -0.020462               0.011200
# kw_min_avg                                 -0.018475              -0.004458
# kw_max_avg                                 -0.080863              -0.034533
# kw_avg_avg                                 -0.073970              -0.017638
# self_reference_min_shares                  -0.098753              -0.022593
# self_reference_max_shares                  -0.127257              -0.117312
# self_reference_avg_sharess                 -0.127431              -0.087186
# weekday_is_monday                                NaN                    NaN
# weekday_is_tuesday                               NaN                    NaN
# weekday_is_wednesday                             NaN                    NaN
# weekday_is_thursday                              NaN                    NaN
# weekday_is_friday                                NaN                    NaN
# weekday_is_saturday                              NaN                    NaN
# weekday_is_sunday                                NaN                    NaN
# is_weekend                                       NaN                    NaN
# LDA_00                                      0.040015               0.044680
# LDA_01                                     -0.103021              -0.054100
# LDA_02                                      0.034294              -0.069186
# LDA_03                                     -0.109100              -0.025607
# LDA_04                                      0.121296               0.104233
# global_subjectivity                        -0.409559              -0.306461
# global_sentiment_polarity                   0.228729               0.282608
# global_rate_positive_words                 -0.143647              -0.123421
# global_rate_negative_words                 -0.398330              -0.513227
# rate_positive_words                         0.084510               0.206099
# rate_negative_words                        -0.382900              -0.462778
# avg_positive_polarity                      -0.233592              -0.188497
# min_positive_polarity                      -0.092627               0.072934
# max_positive_polarity                      -0.289923              -0.360871
# avg_negative_polarity                       1.000000               0.771571
# min_negative_polarity                       0.771571               1.000000
# max_negative_polarity                       0.510056               0.068588
# title_subjectivity                         -0.074862              -0.057639
# title_sentiment_polarity                    0.070888               0.070160
# abs_title_subjectivity                     -0.005927              -0.010531
# abs_title_sentiment_polarity               -0.074678              -0.055097
# shares                                     -0.029894              -0.022607
#
#                                max_negative_polarity  title_subjectivity  \
# timedelta                                  -0.078181           -0.015919
# n_tokens_title                              0.012721            0.077242
# n_tokens_content                            0.265855           -0.001568
# n_unique_tokens                            -0.378397            0.002624
# n_non_stop_words                            0.154978           -0.024744
# n_non_stop_unique_tokens                   -0.286295           -0.023226
# num_hrefs                                   0.041098            0.046263
# num_self_hrefs                             -0.004704           -0.019890
# num_imgs                                    0.043456            0.069984
# num_videos                                  0.008773            0.068546
# average_token_length                       -0.156248           -0.045787
# num_keywords                                0.036227            0.016032
# data_channel_is_lifestyle                        NaN                 NaN
# data_channel_is_entertainment                    NaN                 NaN
# data_channel_is_bus                              NaN                 NaN
# data_channel_is_socmed                           NaN                 NaN
# data_channel_is_tech                             NaN                 NaN
# data_channel_is_world                            NaN                 NaN
# kw_min_min                                 -0.058084           -0.012696
# kw_max_min                                  0.015322            0.001989
# kw_avg_min                                 -0.007756           -0.006138
# kw_min_max                                 -0.004408            0.039002
# kw_max_max                                       NaN                 NaN
# kw_avg_max                                 -0.011573            0.046304
# kw_min_avg                                 -0.003673            0.045342
# kw_max_avg                                 -0.035189            0.096943
# kw_avg_avg                                 -0.035230            0.112369
# self_reference_min_shares                  -0.127915            0.025226
# self_reference_max_shares                  -0.051584            0.021644
# self_reference_avg_sharess                 -0.090098            0.027804
# weekday_is_monday                                NaN                 NaN
# weekday_is_tuesday                               NaN                 NaN
# weekday_is_wednesday                             NaN                 NaN
# weekday_is_thursday                              NaN                 NaN
# weekday_is_friday                                NaN                 NaN
# weekday_is_saturday                              NaN                 NaN
# weekday_is_sunday                                NaN                 NaN
# is_weekend                                       NaN                 NaN
# LDA_00                                     -0.033181           -0.049401
# LDA_01                                     -0.035484            0.049394
# LDA_02                                      0.081156           -0.077400
# LDA_03                                     -0.055861            0.129102
# LDA_04                                      0.029045           -0.053996
# global_subjectivity                        -0.203010            0.151208
# global_sentiment_polarity                  -0.053353            0.024910
# global_rate_positive_words                 -0.086807            0.108803
# global_rate_negative_words                  0.026729            0.086127
# rate_positive_words                        -0.170428           -0.019124
# rate_negative_words                        -0.045819           -0.003869
# avg_positive_polarity                      -0.131920            0.068666
# min_positive_polarity                      -0.242526            0.013970
# max_positive_polarity                      -0.036412            0.052790
# avg_negative_polarity                       0.510056           -0.074862
# min_negative_polarity                       0.068588           -0.057639
# max_negative_polarity                       1.000000           -0.004732
# title_subjectivity                         -0.004732            1.000000
# title_sentiment_polarity                   -0.001271            0.347796
# abs_title_subjectivity                     -0.000895           -0.487172
# abs_title_sentiment_polarity               -0.011095            0.751804
# shares                                     -0.008018            0.051231
#
#                                title_sentiment_polarity  \
# timedelta                                      0.040506
# n_tokens_title                                 0.012936
# n_tokens_content                               0.010093
# n_unique_tokens                               -0.024668
# n_non_stop_words                               0.007683
# n_non_stop_unique_tokens                      -0.043463
# num_hrefs                                      0.039624
# num_self_hrefs                                 0.020374
# num_imgs                                       0.054467
# num_videos                                     0.013867
# average_token_length                          -0.031867
# num_keywords                                   0.035314
# data_channel_is_lifestyle                           NaN
# data_channel_is_entertainment                       NaN
# data_channel_is_bus                                 NaN
# data_channel_is_socmed                              NaN
# data_channel_is_tech                                NaN
# data_channel_is_world                               NaN
# kw_min_min                                     0.040954
# kw_max_min                                     0.025492
# kw_avg_min                                     0.031624
# kw_min_max                                     0.011915
# kw_max_max                                          NaN
# kw_avg_max                                    -0.009390
# kw_min_avg                                     0.023036
# kw_max_avg                                     0.032011
# kw_avg_avg                                     0.046282
# self_reference_min_shares                      0.006420
# self_reference_max_shares                      0.014569
# self_reference_avg_sharess                     0.010495
# weekday_is_monday                                   NaN
# weekday_is_tuesday                                  NaN
# weekday_is_wednesday                                NaN
# weekday_is_thursday                                 NaN
# weekday_is_friday                                   NaN
# weekday_is_saturday                                 NaN
# weekday_is_sunday                                   NaN
# is_weekend                                          NaN
# LDA_00                                         0.023826
# LDA_01                                         0.009850
# LDA_02                                        -0.087095
# LDA_03                                         0.034390
# LDA_04                                         0.019891
# global_subjectivity                            0.059456
# global_sentiment_polarity                      0.231459
# global_rate_positive_words                     0.160559
# global_rate_negative_words                    -0.131947
# rate_positive_words                            0.180186
# rate_negative_words                           -0.197892
# avg_positive_polarity                          0.076882
# min_positive_polarity                         -0.002226
# max_positive_polarity                          0.069879
# avg_negative_polarity                          0.070888
# min_negative_polarity                          0.070160
# max_negative_polarity                         -0.001271
# title_subjectivity                             0.347796
# title_sentiment_polarity                       1.000000
# abs_title_subjectivity                        -0.330201
# abs_title_sentiment_polarity                   0.497617
# shares                                         0.049347
#
#                                abs_title_subjectivity  \
# timedelta                                    0.011551
# n_tokens_title                              -0.147044
# n_tokens_content                             0.012917
# n_unique_tokens                             -0.012172
# n_non_stop_words                             0.035091
# n_non_stop_unique_tokens                     0.001376
# num_hrefs                                    0.007502
# num_self_hrefs                               0.013029
# num_imgs                                    -0.014825
# num_videos                                  -0.017745
# average_token_length                         0.035102
# num_keywords                                -0.011005
# data_channel_is_lifestyle                         NaN
# data_channel_is_entertainment                     NaN
# data_channel_is_bus                               NaN
# data_channel_is_socmed                            NaN
# data_channel_is_tech                              NaN
# data_channel_is_world                             NaN
# kw_min_min                                   0.011688
# kw_max_min                                   0.011086
# kw_avg_min                                   0.013352
# kw_min_max                                  -0.011539
# kw_max_max                                        NaN
# kw_avg_max                                  -0.014370
# kw_min_avg                                  -0.016834
# kw_max_avg                                  -0.015773
# kw_avg_avg                                  -0.026292
# self_reference_min_shares                    0.007687
# self_reference_max_shares                    0.006725
# self_reference_avg_sharess                   0.005698
# weekday_is_monday                                 NaN
# weekday_is_tuesday                                NaN
# weekday_is_wednesday                              NaN
# weekday_is_thursday                               NaN
# weekday_is_friday                                 NaN
# weekday_is_saturday                               NaN
# weekday_is_sunday                                 NaN
# is_weekend                                        NaN
# LDA_00                                       0.001899
# LDA_01                                      -0.064406
# LDA_02                                       0.059835
# LDA_03                                      -0.013777
# LDA_04                                       0.009713
# global_subjectivity                         -0.013282
# global_sentiment_polarity                   -0.031440
# global_rate_positive_words                  -0.136215
# global_rate_negative_words                  -0.049938
# rate_positive_words                         -0.026583
# rate_negative_words                          0.041513
# avg_positive_polarity                        0.012034
# min_positive_polarity                        0.004159
# max_positive_polarity                       -0.017131
# avg_negative_polarity                       -0.005927
# min_negative_polarity                       -0.010531
# max_negative_polarity                       -0.000895
# title_subjectivity                          -0.487172
# title_sentiment_polarity                    -0.330201
# abs_title_subjectivity                       1.000000
# abs_title_sentiment_polarity                -0.466934
# shares                                       0.001383
#
#                                abs_title_sentiment_polarity    shares
# timedelta                                         -0.003452  0.030760
# n_tokens_title                                     0.052412 -0.029364
# n_tokens_content                                   0.008699  0.015086
# n_unique_tokens                                   -0.011069 -0.035034
# n_non_stop_words                                  -0.009165 -0.017310
# n_non_stop_unique_tokens                          -0.035555 -0.057994
# num_hrefs                                          0.062467  0.103244
# num_self_hrefs                                    -0.014513  0.017866
# num_imgs                                           0.078360  0.112764
# num_videos                                         0.057985  0.058826
# average_token_length                              -0.041372 -0.053283
# num_keywords                                       0.023476  0.066856
# data_channel_is_lifestyle                               NaN       NaN
# data_channel_is_entertainment                           NaN       NaN
# data_channel_is_bus                                     NaN       NaN
# data_channel_is_socmed                                  NaN       NaN
# data_channel_is_tech                                    NaN       NaN
# data_channel_is_world                                   NaN       NaN
# kw_min_min                                         0.000749  0.012911
# kw_max_min                                         0.006609  0.080225
# kw_avg_min                                         0.005466  0.075609
# kw_min_max                                         0.045951  0.076184
# kw_max_max                                              NaN       NaN
# kw_avg_max                                         0.036133  0.052994
# kw_min_avg                                         0.053355  0.107681
# kw_max_avg                                         0.093101  0.217315
# kw_avg_avg                                         0.112595  0.253551
# self_reference_min_shares                          0.023186  0.176214
# self_reference_max_shares                          0.019930  0.164040
# self_reference_avg_sharess                         0.025823  0.189135
# weekday_is_monday                                       NaN       NaN
# weekday_is_tuesday                                      NaN       NaN
# weekday_is_wednesday                                    NaN       NaN
# weekday_is_thursday                                     NaN       NaN
# weekday_is_friday                                       NaN       NaN
# weekday_is_saturday                                     NaN       NaN
# weekday_is_sunday                                       NaN       NaN
# is_weekend                                              NaN       NaN
# LDA_00                                            -0.029393  0.029914
# LDA_01                                             0.036301 -0.041236
# LDA_02                                            -0.083721 -0.157547
# LDA_03                                             0.120824  0.119509
# LDA_04                                            -0.047774  0.041229
# global_subjectivity                                0.122751  0.100676
# global_sentiment_polarity                          0.068077  0.050173
# global_rate_positive_words                         0.111645  0.043451
# global_rate_negative_words                         0.057130 -0.007549
# rate_positive_words                                0.004246  0.020366
# rate_negative_words                               -0.026816 -0.048418
# avg_positive_polarity                              0.112884  0.044153
# min_positive_polarity                              0.009505 -0.026570
# max_positive_polarity                              0.076450  0.033658
# avg_negative_polarity                             -0.074678 -0.029894
# min_negative_polarity                             -0.055097 -0.022607
# max_negative_polarity                             -0.011095 -0.008018
# title_subjectivity                                 0.751804  0.051231
# title_sentiment_polarity                           0.497617  0.049347
# abs_title_subjectivity                            -0.466934  0.001383
# abs_title_sentiment_polarity                       1.000000  0.051194
# shares                                             0.051194  1.000000
#
# [60 rows x 60 columns]

# %%
plt.figure(figsize=(27,20))
sns.heatmap(correlation,annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >

# %%
x=df1.drop( ' shares',axis=1)
y=df1[ ' shares']

# %%
sk=SelectKBest(score_func=f_classif,k=20)
x_num=sk.fit_transform(x,y)

# %%
selected_features=x.columns[sk.get_support()]
feature_scores=pd.DataFrame({'feature':x.columns,'score':sk.scores_}).sort_values(by='score',ascending=False)

print("selected features:",selected_features)
print("\nfeature scores:")
print(feature_scores)
# Out:
# selected features: Index([' timedelta', ' n_non_stop_words', ' num_hrefs', ' num_imgs',
#        ' num_keywords', ' kw_max_min', ' kw_avg_min', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess', ' LDA_01',
#        ' LDA_02', ' LDA_03', ' LDA_04', ' global_subjectivity',
#        ' global_sentiment_polarity', ' rate_negative_words'],
#       dtype='object')
#
# feature scores:
#                            feature     score
# 4                 n_non_stop_words  7.166482
# 26                      kw_avg_avg  4.052390
# 25                      kw_max_avg  3.093989
# 40                          LDA_02  2.728063
# 29      self_reference_avg_sharess  2.588136
# 27       self_reference_min_shares  2.402586
# 28       self_reference_max_shares  2.152478
# 41                          LDA_03  1.748324
# 42                          LDA_04  1.503905
# 20                      kw_avg_min  1.448583
# 6                        num_hrefs  1.435169
# 43             global_subjectivity  1.423889
# 24                      kw_min_avg  1.419360
# 19                      kw_max_min  1.405523
# 11                    num_keywords  1.402628
# 8                         num_imgs  1.387811
# 0                        timedelta  1.386313
# 39                          LDA_01  1.365662
# 48             rate_negative_words  1.307359
# 44       global_sentiment_polarity  1.295790
# 7                   num_self_hrefs  1.243526
# 47             rate_positive_words  1.236953
# 5         n_non_stop_unique_tokens  1.229434
# 9                       num_videos  1.210660
# 23                      kw_avg_max  1.205946
# 21                      kw_min_max  1.199867
# 3                  n_unique_tokens  1.191632
# 38                          LDA_00  1.173769
# 1                   n_tokens_title  1.171927
# 45      global_rate_positive_words  1.165232
# 18                      kw_min_min  1.143805
# 56        title_sentiment_polarity  1.112444
# 51           max_positive_polarity  1.104325
# 50           min_positive_polarity  1.099692
# 55              title_subjectivity  1.093900
# 10            average_token_length  1.089917
# 49           avg_positive_polarity  1.058369
# 58    abs_title_sentiment_polarity  1.052946
# 2                 n_tokens_content  1.048909
# 54           max_negative_polarity  1.044192
# 57          abs_title_subjectivity  1.031427
# 46      global_rate_negative_words  1.029868
# 53           min_negative_polarity  1.005739
# 52           avg_negative_polarity  0.971067
# 12       data_channel_is_lifestyle       NaN
# 13   data_channel_is_entertainment       NaN
# 14             data_channel_is_bus       NaN
# 15          data_channel_is_socmed       NaN
# 16            data_channel_is_tech       NaN
# 17           data_channel_is_world       NaN
# 22                      kw_max_max       NaN
# 30               weekday_is_monday       NaN
# 31              weekday_is_tuesday       NaN
# 32            weekday_is_wednesday       NaN
# 33             weekday_is_thursday       NaN
# 34               weekday_is_friday       NaN
# 35             weekday_is_saturday       NaN
# 36               weekday_is_sunday       NaN
# 37                      is_weekend       NaN

# %%
x_selected=x[selected_features]

# %%
x_selected.columns

# %%
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x_selected)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
print(f"""
x train shape:{x_train.shape}
x test shape:{x_test.shape}
y train shape:{y_train.shape}
y test shape:{y_test.shape}
""")
